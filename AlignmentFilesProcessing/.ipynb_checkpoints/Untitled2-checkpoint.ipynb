# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
data=pd.read_csv("Align_Liver_HW_2h_L0_Liver_HW_2h_L1.txt",header=None)
L0=np.array(data.iloc[list(range(0,data.shape[0],2)),0])
L1=np.array(data.iloc[list(range(1,data.shape[0],2)),0])

tempdata=pd.DataFrame()
tempdata["L0"]=L0
tempdata["L1"]=L1
tempdata.to_csv("_Align_Liver_HW_2h_L0_Liver_HW_2h_L1.csv")

# %%
data=pd.read_csv("Align_Liver_HW_2h_L1_Liver_HW_2h_L2.txt",header=None)
L11=np.array(data.iloc[list(range(0,data.shape[0],2)),0])
L2=np.array(data.iloc[list(range(1,data.shape[0],2)),0])

tempdata1=pd.DataFrame()
tempdata1["L1"]=L11
tempdata1["L2"]=L2

tempdata1.to_csv("_Align_Liver_HW_2h_L1_Liver_HW_2h_L2.csv")

# %%
Finaldata=pd.merge(tempdata,tempdata1,on="L1")
print(Finaldata.shape)
Finaldata.head()
# Out:
# (11438, 3)
#          L0        L1        L2
# 0  0.007245  0.007376  0.007533
# 1  0.011120  0.011335  0.011479
# 2  0.015976  0.018264  0.016587
# 3  0.019974  0.022393  0.020518
# 4  0.023238  0.025839  0.023912

# %%
data=pd.read_csv("Align_Liver_HW_2h_L2_Liver_HW_2h_L3.txt",header=None)
L2=np.array(data.iloc[list(range(0,data.shape[0],2)),0])
L3=np.array(data.iloc[list(range(1,data.shape[0],2)),0])

tempdata1=pd.DataFrame()
tempdata1["L2"]=L2
tempdata1["L3"]=L3
Finaldata=Finaldata.merge(tempdata1,on="L2")

tempdata1.to_csv("_Align_Liver_HW_2h_L2_Liver_HW_2h_L3.csv")

# %%
print(Finaldata.shape)
Finaldata.head()
# Out:
# (11342, 4)
#          L0        L1        L2        L3
# 0  0.007245  0.007376  0.007533  0.007531
# 1  0.011120  0.011335  0.011479  0.011537
# 2  0.015976  0.018264  0.016587  0.014875
# 3  0.019974  0.022393  0.020518  0.019827
# 4  0.023238  0.025839  0.023912  0.023983

# %%
data=pd.read_csv("Align_Liver_HW_2h_L3_Liver_HW_2h_L6.txt",header=None)
L3=np.array(data.iloc[list(range(0,data.shape[0],2)),0])
L6=np.array(data.iloc[list(range(1,data.shape[0],2)),0])

tempdata1=pd.DataFrame()
tempdata1["L3"]=L3
tempdata1["L6"]=L6
Finaldata=Finaldata.merge(tempdata1,on="L3")

tempdata1.to_csv("_Align_Liver_HW_2h_L3_Liver_HW_2h_L6.csv")

# %%
print(Finaldata.shape)
Finaldata.head()
# Out:
# (11256, 5)
#          L0        L1        L2        L3        L6
# 0  0.007245  0.007376  0.007533  0.007531  0.007505
# 1  0.011120  0.011335  0.011479  0.011537  0.011518
# 2  0.015976  0.018264  0.016587  0.014875  0.015011
# 3  0.019974  0.022393  0.020518  0.019827  0.022007
# 4  0.023238  0.025839  0.023912  0.023983  0.026057

# %%
data=pd.read_csv("Align_Liver_HW_2h_L6_Liver_HW_2h_L7.txt",header=None)
L6=np.array(data.iloc[list(range(0,data.shape[0],2)),0])
L7=np.array(data.iloc[list(range(1,data.shape[0],2)),0])

tempdata1=pd.DataFrame()
tempdata1["L6"]=L6
tempdata1["L7"]=L7
Finaldata=Finaldata.merge(tempdata1,on="L6")

tempdata1.to_csv("_Align_Liver_HW_2h_L6_Liver_HW_2h_L7.csv")

# %%
print(Finaldata.shape)
Finaldata.head()
# Out:
# (11164, 6)
#          L0        L1        L2        L3        L6        L7
# 0  0.007245  0.007376  0.007533  0.007531  0.007505  0.007538
# 1  0.011120  0.011335  0.011479  0.011537  0.011518  0.011588
# 2  0.015976  0.018264  0.016587  0.014875  0.015011  0.016863
# 3  0.023238  0.025839  0.023912  0.023983  0.026057  0.020769
# 4  0.033149  0.036059  0.028881  0.027495  0.029470  0.024296

# %%
data=pd.read_csv("Align_Liver_HW_2h_L7_Liver_HW_2h_L9.txt",header=None)
L7=np.array(data.iloc[list(range(0,data.shape[0],2)),0])
L9=np.array(data.iloc[list(range(1,data.shape[0],2)),0])

tempdata1=pd.DataFrame()
tempdata1["L7"]=L7
tempdata1["L9"]=L9
Finaldata=Finaldata.merge(tempdata1,on="L7")

tempdata1.to_csv("_Align_Liver_HW_2h_L7_Liver_HW_2h_L9.csv")

# %%
print(Finaldata.shape)
Finaldata.head()
# Out:
# (11014, 7)
#          L0        L1        L2        L3        L6        L7        L9
# 0  0.007245  0.007376  0.007533  0.007531  0.007505  0.007538  0.007542
# 1  0.011120  0.011335  0.011479  0.011537  0.011518  0.011588  0.011615
# 2  0.015976  0.018264  0.016587  0.014875  0.015011  0.016863  0.016788
# 3  0.023238  0.025839  0.023912  0.023983  0.026057  0.020769  0.020758
# 4  0.033149  0.036059  0.028881  0.027495  0.029470  0.024296  0.024146

# %%
data=pd.read_csv("Align_Liver_HW_2h_L9_Liver_HW_2h_L13.txt",header=None)
L9=np.array(data.iloc[list(range(0,data.shape[0],2)),0])
L13=np.array(data.iloc[list(range(1,data.shape[0],2)),0])

tempdata1=pd.DataFrame()
tempdata1["L9"]=L9
tempdata1["L13"]=L13
Finaldata=Finaldata.merge(tempdata1,on="L9")

tempdata1.to_csv("_Align_Liver_HW_2h_L9_Liver_HW_2h_L13.csv")

# %%
print(Finaldata.shape)
Finaldata.head()
# Out:
# (10925, 8)
#          L0        L1        L2        L3        L6        L7        L9  \
# 0  0.007245  0.007376  0.007533  0.007531  0.007505  0.007538  0.007542
# 1  0.011120  0.011335  0.011479  0.011537  0.011518  0.011588  0.011615
# 2  0.015976  0.018264  0.016587  0.014875  0.015011  0.016863  0.016788
# 3  0.023238  0.025839  0.023912  0.023983  0.026057  0.020769  0.020758
# 4  0.033149  0.036059  0.028881  0.027495  0.029470  0.024296  0.024146
#
#         L13
# 0  0.007837
# 1  0.012371
# 2  0.016256
# 3  0.019529
# 4  0.024470

# %%
data=pd.read_csv("Align_Liver_HW_2h_L13_Liver_HW_2h_L16.txt",header=None)
L13=np.array(data.iloc[list(range(0,data.shape[0],2)),0])
L16=np.array(data.iloc[list(range(1,data.shape[0],2)),0])

tempdata1=pd.DataFrame()
tempdata1["L13"]=L13
tempdata1["L16"]=L16
Finaldata=Finaldata.merge(tempdata1,on="L13")

tempdata1.to_csv("_Align_Liver_HW_2h_L13_Liver_HW_2h_L16.csv")

# %%
print(Finaldata.shape)
Finaldata.head()
# Out:
# (10753, 9)
#          L0        L1        L2        L3        L6        L7        L9  \
# 0  0.011120  0.011335  0.011479  0.011537  0.011518  0.011588  0.011615
# 1  0.015976  0.018264  0.016587  0.014875  0.015011  0.016863  0.016788
# 2  0.023238  0.025839  0.023912  0.023983  0.026057  0.020769  0.020758
# 3  0.033149  0.036059  0.028881  0.027495  0.029470  0.024296  0.024146
# 4  0.036439  0.039416  0.033066  0.030946  0.034518  0.029415  0.027540
#
#         L13       L16
# 0  0.012371  0.007470
# 1  0.016256  0.011806
# 2  0.019529  0.017120
# 3  0.024470  0.021041
# 4  0.028471  0.024430

# %%
data=pd.read_csv("Align_Liver_HW_2h_L16_Liver_HW_2h_L21.txt",header=None)
L16=np.array(data.iloc[list(range(0,data.shape[0],2)),0])
L21=np.array(data.iloc[list(range(1,data.shape[0],2)),0])

tempdata1=pd.DataFrame()
tempdata1["L16"]=L16
tempdata1["L21"]=L21
Finaldata=Finaldata.merge(tempdata1,on="L16")

tempdata1.to_csv("_Align_Liver_HW_2h_L16_Liver_HW_2h_L21.csv")

# %%
print(Finaldata.shape)
Finaldata.head()
# Out:
# (10672, 10)
#          L0        L1        L2        L3        L6        L7        L9  \
# 0  0.011120  0.011335  0.011479  0.011537  0.011518  0.011588  0.011615
# 1  0.015976  0.018264  0.016587  0.014875  0.015011  0.016863  0.016788
# 2  0.023238  0.025839  0.023912  0.023983  0.026057  0.020769  0.020758
# 3  0.033149  0.036059  0.028881  0.027495  0.029470  0.024296  0.024146
# 4  0.036439  0.039416  0.033066  0.030946  0.034518  0.029415  0.027540
#
#         L13       L16       L21
# 0  0.012371  0.007470  0.007344
# 1  0.016256  0.011806  0.015690
# 2  0.019529  0.017120  0.034753
# 3  0.024470  0.021041  0.038120
# 4  0.028471  0.024430  0.043276

# %%
data=pd.read_csv("Align_Liver_HW_2h_L21_Liver_HW_2h_L24.txt",header=None)
L21=np.array(data.iloc[list(range(0,data.shape[0],2)),0])
L24=np.array(data.iloc[list(range(1,data.shape[0],2)),0])

tempdata1=pd.DataFrame()
tempdata1["L21"]=L21
tempdata1["L24"]=L24
Finaldata=Finaldata.merge(tempdata1,on="L21")

tempdata1.to_csv("_Align_Liver_HW_2h_L21_Liver_HW_2h_L24.csv")

# %%
print(Finaldata.shape)
Finaldata.head()
# Out:
# (10438, 11)
#          L0        L1        L2        L3        L6        L7        L9  \
# 0  0.011120  0.011335  0.011479  0.011537  0.011518  0.011588  0.011615
# 1  0.015976  0.018264  0.016587  0.014875  0.015011  0.016863  0.016788
# 2  0.023238  0.025839  0.023912  0.023983  0.026057  0.020769  0.020758
# 3  0.033149  0.036059  0.028881  0.027495  0.029470  0.024296  0.024146
# 4  0.036439  0.039416  0.033066  0.030946  0.034518  0.029415  0.027540
#
#         L13       L16       L21       L24
# 0  0.012371  0.007470  0.007344  0.007395
# 1  0.016256  0.011806  0.015690  0.017279
# 2  0.019529  0.017120  0.034753  0.034839
# 3  0.024470  0.021041  0.038120  0.038256
# 4  0.028471  0.024430  0.043276  0.041641

# %%
data=pd.read_csv("Align_Liver_HW_2h_L24_Liver_HW_2h_L31.txt",header=None)
L24=np.array(data.iloc[list(range(0,data.shape[0],2)),0])
L31=np.array(data.iloc[list(range(1,data.shape[0],2)),0])

tempdata1=pd.DataFrame()
tempdata1["L24"]=L24
tempdata1["L31"]=L31
Finaldata=Finaldata.merge(tempdata1,on="L24")

tempdata1.to_csv("_Align_Liver_HW_2h_L24_Liver_HW_2h_L31.csv")

# %%
print(Finaldata.shape)
Finaldata.head()
# Out:
# (10316, 12)
#          L0        L1        L2        L3        L6        L7        L9  \
# 0  0.011120  0.011335  0.011479  0.011537  0.011518  0.011588  0.011615
# 1  0.015976  0.018264  0.016587  0.014875  0.015011  0.016863  0.016788
# 2  0.023238  0.025839  0.023912  0.023983  0.026057  0.020769  0.020758
# 3  0.033149  0.036059  0.028881  0.027495  0.029470  0.024296  0.024146
# 4  0.036439  0.039416  0.033066  0.030946  0.034518  0.029415  0.027540
#
#         L13       L16       L21       L24       L31
# 0  0.012371  0.007470  0.007344  0.007395  0.007526
# 1  0.016256  0.011806  0.015690  0.017279  0.016357
# 2  0.019529  0.017120  0.034753  0.034839  0.034257
# 3  0.024470  0.021041  0.038120  0.038256  0.037647
# 4  0.028471  0.024430  0.043276  0.041641  0.042716

# %%
# Finaldata.plot(kind="scatter",x="L0",y="L31")
plt.figure(figsize=(16,7))
plt.rc('font', size=20) 
plt.scatter(Finaldata.L0,Finaldata.L0-Finaldata.L1,alpha=0.5,label="[L0,L1]")
# plt.scatter(Finaldata.L0,Finaldata.L0-Finaldata.L7,alpha=0.5,label="[L0,L7]")
# plt.scatter(Finaldata.L0,Finaldata.L0-Finaldata.L16,alpha=0.5,label="[L0,L16]")
# plt.scatter(Finaldata.L0,Finaldata.L0-Finaldata.L31,alpha=0.5,label="[L0,L31]") 

plt.hlines(0,xmin=min(data.iloc[:,0]),xmax=max(data.iloc[:,0]),color='m')

plt.ylabel("Retention time deviation (min)")
plt.xlabel("Retention time (min)")
plt.legend()

# %%
dx=pd.read_csv("temp2_31.txt",header=None)
dx.columns=["t","s1","s2","r1","r2"]
dx
# Out:
#           t     s1     s2         r1         r2
# 0      2502   2503   2551    9.64056    9.82594
# 1      2503   2504   2552    9.64420    9.82952
# 2      2504   2505   2553    9.64784    9.83298
# 3      2505   2506   2554    9.65139    9.83656
# 4      2506   2507   2555    9.65505    9.84006
# ...     ...    ...    ...        ...        ...
# 8994  11496  11621  11977  119.98821  119.98811
# 8995  11497  11622  11978  119.99184  119.99176
# 8996  11498  11623  11979  119.99552  119.99541
# 8997  11499  11624  11980  119.99921  119.99904
# 8998  11500  11625  11981  120.00285  120.00267
#
# [8999 rows x 5 columns]

# %%
plt.scatter(dx.r1,dx.r1-dx.r2)

# %%
plt.scatter(Finaldata.L2,Finaldata.L2-Finaldata.L31,alpha=0.5,label="[L2,L31]")

# %%
tempFinaldata=pd.DataFrame()
tempFinaldata["L1"]=abs(Finaldata["L1"]-Finaldata["L0"])
tempFinaldata["L2"]=abs(Finaldata["L2"]-Finaldata["L0"])
tempFinaldata["L3"]=abs(Finaldata["L3"]-Finaldata["L0"])
tempFinaldata["L6"]=abs(Finaldata["L6"]-Finaldata["L0"])
tempFinaldata["L7"]=abs(Finaldata["L7"]-Finaldata["L0"])
tempFinaldata["L13"]=abs(Finaldata["L13"]-Finaldata["L0"])
tempFinaldata["L16"]=abs(Finaldata["L16"]-Finaldata["L0"])
tempFinaldata["L21"]=abs(Finaldata["L21"]-Finaldata["L0"])
tempFinaldata["L24"]=abs(Finaldata["L24"]-Finaldata["L0"])
tempFinaldata["L31"]=abs(Finaldata["L31"]-Finaldata["L0"]) 
tempFinaldata
# Out:
#                L1        L2        L3        L6        L7         L13  \
# 0        0.010905  0.000359  0.000418  0.000398  0.000468    0.009869
# 1        0.013689  0.000611  0.001101  0.000965  0.000886    0.015696
# 2        0.020638  0.000673  0.000745  0.002819  0.002470    0.019529
# 3        0.030239  0.004269  0.005654  0.003679  0.008853    0.024470
# 4        0.033461  0.003372  0.005493  0.001921  0.007024    0.028471
# ...           ...       ...       ...       ...       ...         ...
# 10311  119.979200  0.001000  0.007400  0.006800  0.008700  119.973700
# 10312  119.982800  0.001200  0.007600  0.007100  0.009000  119.977100
# 10313  119.986500  0.001300  0.007800  0.009200  0.009100  119.978700
# 10314  119.995400  0.001700  0.000800  0.002600  0.002300  119.995800
# 10315  119.998800  0.001900  0.001000  0.002900  0.002600  119.999100
#
#               L16         L21         L24         L31
# 0        0.007470    0.007344    0.007395    0.007526
# 1        0.011806    0.015690    0.014673    0.015595
# 2        0.017120    0.011724    0.011638    0.012220
# 3        0.021041    0.028179    0.028042    0.028652
# 4        0.024430    0.029601    0.031236    0.030161
# ...           ...         ...         ...         ...
# 10311  119.975800  119.973100  119.972300  119.971500
# 10312  119.979400  119.976600  119.975700  119.974800
# 10313  119.981500  119.980300  119.979300  119.978400
# 10314  119.996400  119.997000  119.996900  119.996000
# 10315  119.999800  120.000500  120.000300  119.999300
#
# [10316 rows x 10 columns]

# %%
import seaborn as sns

plt.figure(figsize=(10,8))

# sns.distplot(tempFinaldata.L1.astype(float) ,
#              hist=False, kde=True, bins=15, 
#              hist_kws={'edgecolor':'black'},
#              kde_kws={'linewidth': 1,"bw_adjust":3},label="Decoy")

# sns.distplot(tempFinaldata.L1.astype(float) ,kde=True, bins=50, hist=False,
#              kde_kws={'linewidth': 1,"bw_adjust":3},label="1")

# sns.distplot(tempFinaldata.L13.astype(float) ,kde=True, bins=50, hist=False,
#              kde_kws={'linewidth': 1,"bw_adjust":3},label="13")
# sns.distplot(tempFinaldata.L16.astype(float) ,kde=True, bins=50, hist=False,
#              kde_kws={'linewidth': 1,"bw_adjust":3},label="16")
# sns.distplot(tempFinaldata.L21.astype(float) ,kde=True, bins=50, hist=False,
#              kde_kws={'linewidth': 1,"bw_adjust":3},label="21")
# sns.distplot(tempFinaldata.L24.astype(float) ,kde=True, bins=50, hist=False,
#              kde_kws={'linewidth': 1,"bw_adjust":3},label="24")


sns.distplot(abs(Finaldata["L2"]-Finaldata["L3"])*60 ,kde=True, bins=100, hist=False,
             kde_kws={'linewidth': 1,"bw_adjust":1.5,"linewidth":2},label="L2,L1")

sns.distplot(abs(Finaldata["L3"]-Finaldata["L6"])*60 ,kde=True, bins=100, hist=False,
             kde_kws={'linewidth': 1,"bw_adjust":1.5,"linewidth":2},label="L2,L1")

# sns.distplot(abs(Finaldata["L21"]-Finaldata["L13"])*60 ,kde=True, bins=100, hist=False,
#              kde_kws={'linewidth': 1,"bw_adjust":3,"linewidth":2},label="L21,L13")


sns.distplot(abs(Finaldata["L21"]-Finaldata["L24"])*60 ,kde=True, bins=100, hist=False,
             kde_kws={'linewidth': 1,"bw_adjust":1.5,"linewidth":2},label="L21,L24")


sns.distplot(abs(Finaldata["L24"]-Finaldata["L31"])*60 ,kde=True, bins=100, hist=False,
             kde_kws={'linewidth': 1,"bw_adjust":1.5,"linewidth":2},label="L24,L31")

# sns.distplot(tempFinaldata.L2.astype(float) ,kde=True, bins=15, hist=False,
#              kde_kws={'linewidth': 1,"bw_adjust":3},label="2")

plt.rc({"lines.linewidth":10})
plt.legend()
plt.xlabel("Retention time shift (Sec)")
plt.savefig(f"Retention time shift.jpeg",dpi=900, bbox_inches = "tight")
# Out:
# C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
import seaborn as sns

plt.figure(figsize=(10,8))
 
sns.distplot(abs(Finaldata["L2"]-Finaldata["L31"]) ,kde=True, bins=100, hist=False,
             kde_kws={'linewidth': 1,"bw_adjust":3,"linewidth":2},label="L21,L13")


sns.distplot(abs(Finaldata["L3"]-Finaldata["L31"]) ,kde=True, bins=100, hist=False,
             kde_kws={'linewidth': 1,"bw_adjust":3,"linewidth":2},label="L21,L24")


sns.distplot(abs(Finaldata["L6"]-Finaldata["L31"]) ,kde=True, bins=100, hist=False,
             kde_kws={'linewidth': 1,"bw_adjust":3,"linewidth":2},label="L24,L31")
 

plt.rc({"lines.linewidth":10})
plt.legend()
# Out:
# C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\hmdebern.UTMB-USERS-M\.conda\envs\myenv\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
