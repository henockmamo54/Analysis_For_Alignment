# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
organ = "liver"
# organ = "heart"
# organ = "muscle"
# organ = "kidney"

# %% [markdown]
# Load data
# ===

# %%
path= '../data/alignment/'+organ
filelist=os.listdir(path)
filelist.remove("compare.csv")
proteinlist= []
for p in filelist:
    if p.endswith(".csv"):
        proteinlist.append(p)            

data=pd.DataFrame()
for  p in proteinlist:
    d=pd.read_csv(os.path.join(path,p))
    d["Protein"]=p.replace('.csv','')
    data=pd.concat([data,d])       

    data["diff"]= abs(data["old_Rsquared"] - data["new_Rsquared"])    
# data=data[data.NDP >=4]
print(data.shape)
# Out:
# (27307, 31)

# %%
data_align=data
data_align.head()
# Out:
#    proteinName   peptideSeq  charge  old_Rsquared  new_Rsquared  NDP  \
# 0  1433B_MOUSE     NLLSVAYK       2      0.953825      0.973210   12
# 1  1433B_MOUSE    EMQPTHPIR       3      0.936609      0.980352   12
# 2  1433B_MOUSE   DSTLIMQLLR       2      0.985986      0.997529   12
# 3  1433B_MOUSE  YLSEVASGENK       2      0.986787      0.996046   12
# 4  1433B_MOUSE   DSTLImQLLR       2     -0.132288      0.291445   12
#
#    rateconstant     sigma     Abundance  MassToCharge  ...  lowerci_old  \
# 0       0.16249  0.013771  1.432731e+09     454.26599  ...     0.140399
# 1       0.13397  0.011820  1.813278e+08     370.19043  ...     0.111041
# 2       0.19307  0.009791  1.747584e+09     595.33411  ...     0.174313
# 3       0.23813  0.011572  1.513652e+08     598.79327  ...     0.211593
# 4       0.10303  0.026401  4.965206e+07     603.33154  ...     0.039029
#
#    upperci_old  sigma_old  lowerci_new upperci_new  sigma_new old_pearson  \
# 0     0.184581   0.010037     0.145470    0.179510   0.007733    0.990368
# 1     0.156899   0.010417     0.120541    0.147399   0.006102    0.981593
# 2     0.211827   0.008522     0.185113    0.201027   0.003615    0.994336
# 3     0.264667   0.012057     0.223234    0.253026   0.006768    0.997019
# 4     0.167031   0.029078     0.045577    0.160483   0.026103    0.743668
#
#   new_pearson      Protein      diff
# 0    0.994301  1433B_MOUSE  0.019385
# 1    0.993457  1433B_MOUSE  0.043742
# 2    0.999524  1433B_MOUSE  0.011544
# 3    0.998608  1433B_MOUSE  0.009259
# 4    0.830570  1433B_MOUSE  0.423734
#
# [5 rows x 31 columns]

# %%
print("Rsquared >= 95 \t Original d2ome =",data[data.old_Rsquared>=0.95].shape[0]/data.shape[0])
print("Rsquared >= 90 \t Original d2ome =",data[data.old_Rsquared>=0.9].shape[0]/data.shape[0])
print("Rsquared >= 80 \t Original d2ome =", data[data.old_Rsquared>=0.8].shape[0]/data.shape[0])
print("Rsquared >= 75 \t Original d2ome =",data[data.old_Rsquared>=0.75].shape[0]/data.shape[0])
# Out:
# Rsquared >= 95 	 Original d2ome = 0.2519866700845937
# Rsquared >= 90 	 Original d2ome = 0.3805617607206943
# Rsquared >= 80 	 Original d2ome = 0.5016296187790676
# Rsquared >= 75 	 Original d2ome = 0.5383967480865712

# %%
print("Rsquared >= 95 \t Original d2ome =",data[data.old_Rsquared>=0.95].shape[0])
print("Rsquared >= 90 \t Original d2ome =",data[data.old_Rsquared>=0.9].shape[0])
print("Rsquared >= 80 \t Original d2ome =", data[data.old_Rsquared>=0.8].shape[0])
print("Rsquared >= 75 \t Original d2ome =",data[data.old_Rsquared>=0.75].shape[0])
print("Rsquared <= 75 \t Original d2ome =",data[data.old_Rsquared<=0.75].shape[0])
# Out:
# Rsquared >= 95 	 Original d2ome = 6881
# Rsquared >= 90 	 Original d2ome = 10392
# Rsquared >= 80 	 Original d2ome = 13698
# Rsquared >= 75 	 Original d2ome = 14702
# Rsquared <= 75 	 Original d2ome = 12423

# %%
alignmentdata=[data[data.old_Rsquared>=0.95].shape[0],data[data.old_Rsquared>=0.9].shape[0], data[data.old_Rsquared>=0.8].shape[0],
data[data.old_Rsquared>=0.75].shape[0],data[data.old_Rsquared<=0.75].shape[0]]

# %%
filelist
# Out:
# ['1433B_MOUSE.csv',
#  '1433E_MOUSE.csv',
#  '1433F_MOUSE.csv',
#  '1433G_MOUSE.csv',
#  '1433T_MOUSE.csv',
#  '1433Z_MOUSE.csv',
#  '2A5A_MOUSE.csv',
#  '2A5E_MOUSE.csv',
#  '2AAA_MOUSE.csv',
#  '2AAB_MOUSE.csv',
#  '2ABA_MOUSE.csv',
#  '2ABB_MOUSE.csv',
#  '3BHS3_MOUSE.csv',
#  '3BHS5_MOUSE.csv',
#  '3BHS7_MOUSE.csv',
#  '3HAO_MOUSE.csv',
#  '3HIDH_MOUSE.csv',
#  '4EBP2_MOUSE.csv',
#  '6PGD_MOUSE.csv',
#  '6PGL_MOUSE.csv',
#  'A16A1_MOUSE.csv',
#  'A1AG1_MOUSE.csv',
#  'A1AG2_MOUSE.csv',
#  'A1AT1_MOUSE.csv',
#  'A1AT2_MOUSE.csv',
#  'A1AT3_MOUSE.csv',
#  'A1AT4_MOUSE.csv',
#  'A1AT5_MOUSE.csv',
#  'A1CF_MOUSE.csv',
#  'A2AP_MOUSE.csv',
#  'AAAD_MOUSE.csv',
#  'AACS_MOUSE.csv',
#  'AADAT_MOUSE.csv',
#  'AAKB1_MOUSE.csv',
#  'AAKG1_MOUSE.csv',
#  'AAPK1_MOUSE.csv',
#  'AAPK2_MOUSE.csv',
#  'AASD1_MOUSE.csv',
#  'AASS_MOUSE.csv',
#  'AATC_MOUSE.csv',
#  'AATM_MOUSE.csv',
#  'ABC8B_MOUSE.csv',
#  'ABCA6_MOUSE.csv',
#  'ABCB6_MOUSE.csv',
#  'ABCB7_MOUSE.csv',
#  'ABCBA_MOUSE.csv',
#  'ABCBB_MOUSE.csv',
#  'ABCD3_MOUSE.csv',
#  'ABCE1_MOUSE.csv',
#  'ABCF1_MOUSE.csv',
#  'ABCF2_MOUSE.csv',
#  'ABCG2_MOUSE.csv',
#  'ABCG8_MOUSE.csv',
#  'ABD12_MOUSE.csv',
#  'ABHD3_MOUSE.csv',
#  'ABHD6_MOUSE.csv',
#  'ABHDB_MOUSE.csv',
#  'ABHEB_MOUSE.csv',
#  'ABHGA_MOUSE.csv',
#  'ABRAL_MOUSE.csv',
#  'ABRX2_MOUSE.csv',
#  'ACACA_MOUSE.csv',
#  'ACACB_MOUSE.csv',
#  'ACAD8_MOUSE.csv',
#  'ACAD9_MOUSE.csv',
#  'ACADL_MOUSE.csv',
#  'ACADM_MOUSE.csv',
#  'ACADS_MOUSE.csv',
#  'ACADV_MOUSE.csv',
#  'ACATN_MOUSE.csv',
#  'ACBD5_MOUSE.csv',
#  'ACBP_MOUSE.csv',
#  'ACD10_MOUSE.csv',
#  'ACD11_MOUSE.csv',
#  'ACDSB_MOUSE.csv',
#  'ACL6A_MOUSE.csv',
#  'ACLY_MOUSE.csv',
#  'ACNT1_MOUSE.csv',
#  'ACO12_MOUSE.csv',
#  'ACO13_MOUSE.csv',
#  'ACOC_MOUSE.csv',
#  'ACON_MOUSE.csv',
#  'ACOT1_MOUSE.csv',
#  'ACOT2_MOUSE.csv',
#  'ACOT3_MOUSE.csv',
#  'ACOT4_MOUSE.csv',
#  'ACOT8_MOUSE.csv',
#  'ACOX1_MOUSE.csv',
#  'ACOX2_MOUSE.csv',
#  'ACOX3_MOUSE.csv',
#  'ACPM_MOUSE.csv',
#  'ACSA_MOUSE.csv',
#  'ACSF2_MOUSE.csv',
#  'ACSF3_MOUSE.csv',
#  'ACSL1_MOUSE.csv',
#  'ACSL4_MOUSE.csv',
#  'ACSL5_MOUSE.csv',
#  'ACSM1_MOUSE.csv',
#  'ACSM3_MOUSE.csv',
#  'ACSM5_MOUSE.csv',
#  'ACSS3_MOUSE.csv',
#  'ACTBL_MOUSE.csv',
#  'ACTB_MOUSE.csv',
#  'ACTC_MOUSE.csv',
#  'ACTN1_MOUSE.csv',
#  'ACTN4_MOUSE.csv',
#  'ACTS_MOUSE.csv',
#  'ACTY_MOUSE.csv',
#  'ACTZ_MOUSE.csv',
#  'ACY1_MOUSE.csv',
#  'ACY3_MOUSE.csv',
#  'ADH1_MOUSE.csv',
#  'ADH4_MOUSE.csv',
#  'ADHX_MOUSE.csv',
#  'ADK_MOUSE.csv',
#  'ADPGK_MOUSE.csv',
#  'ADPRM_MOUSE.csv',
#  'ADPRS_MOUSE.csv',
#  'ADRM1_MOUSE.csv',
#  'ADRO_MOUSE.csv',
#  'ADT1_MOUSE.csv',
#  'ADT2_MOUSE.csv',
#  'ADX_MOUSE.csv',
#  'AEDO_MOUSE.csv',
#  'AFAD_MOUSE.csv',
#  'AFG1L_MOUSE.csv',
#  'AFG32_MOUSE.csv',
#  'AGFG2_MOUSE.csv',
#  'AGK_MOUSE.csv',
#  'AGM1_MOUSE.csv',
#  'AGT2_MOUSE.csv',
#  'AHSA1_MOUSE.csv',
#  'AIFM1_MOUSE.csv',
#  'AIMP1_MOUSE.csv',
#  'AIMP2_MOUSE.csv',
#  'AK1A1_MOUSE.csv',
#  'AK1CD_MOUSE.csv',
#  'AK1D1_MOUSE.csv',
#  'AKA10_MOUSE.csv',
#  'AKAP1_MOUSE.csv',
#  'AKC1H_MOUSE.csv',
#  'AKCL2_MOUSE.csv',
#  'AKT2_MOUSE.csv',
#  'AL1A1_MOUSE.csv',
#  'AL1A7_MOUSE.csv',
#  'AL1B1_MOUSE.csv',
#  'AL1L1_MOUSE.csv',
#  'AL3A2_MOUSE.csv',
#  'AL4A1_MOUSE.csv',
#  'AL7A1_MOUSE.csv',
#  'AL8A1_MOUSE.csv',
#  'AL9A1_MOUSE.csv',
#  'ALAT1_MOUSE.csv',
#  'ALAT2_MOUSE.csv',
#  'ALBU_MOUSE.csv',
#  'ALD2_MOUSE.csv',
#  'ALDH2_MOUSE.csv',
#  'ALDOA_MOUSE.csv',
#  'ALDOB_MOUSE.csv',
#  'ALDR_MOUSE.csv',
#  'ALG2_MOUSE.csv',
#  'ALG5_MOUSE.csv',
#  'ALKMO_MOUSE.csv',
#  'ALR_MOUSE.csv',
#  'AMACR_MOUSE.csv',
#  'AMBP_MOUSE.csv',
#  'AMPB_MOUSE.csv',
#  'AMPE_MOUSE.csv',
#  'AMPL_MOUSE.csv',
#  'AMPN_MOUSE.csv',
#  'AMRP_MOUSE.csv',
#  'AMY1_MOUSE.csv',
#  'AN32A_MOUSE.csv',
#  'AN32B_MOUSE.csv',
#  'AN32E_MOUSE.csv',
#  'ANGL3_MOUSE.csv',
#  'ANM5_MOUSE.csv',
#  'ANR28_MOUSE.csv',
#  'ANR52_MOUSE.csv',
#  'ANT3_MOUSE.csv',
#  'ANX11_MOUSE.csv',
#  'ANXA1_MOUSE.csv',
#  'ANXA2_MOUSE.csv',
#  'ANXA3_MOUSE.csv',
#  'ANXA4_MOUSE.csv',
#  'ANXA5_MOUSE.csv',
#  'ANXA6_MOUSE.csv',
#  'ANXA7_MOUSE.csv',
#  'AOFA_MOUSE.csv',
#  'AOFB_MOUSE.csv',
#  'AOXA_MOUSE.csv',
#  'AOXC_MOUSE.csv',
#  'AP1B1_MOUSE.csv',
#  'AP1G1_MOUSE.csv',
#  'AP1M1_MOUSE.csv',
#  'AP2A1_MOUSE.csv',
#  'AP2A2_MOUSE.csv',
#  'AP2B1_MOUSE.csv',
#  'AP2M1_MOUSE.csv',
#  'AP2S1_MOUSE.csv',
#  'AP3B1_MOUSE.csv',
#  'AP3D1_MOUSE.csv',
#  'AP4A_MOUSE.csv',
#  'APEH_MOUSE.csv',
#  'APEX1_MOUSE.csv',
#  'API5_MOUSE.csv',
#  'APMAP_MOUSE.csv',
#  'APOA1_MOUSE.csv',
#  'APOA2_MOUSE.csv',
#  'APOA4_MOUSE.csv',
#  'APOA5_MOUSE.csv',
#  'APOB_MOUSE.csv',
#  'APOC1_MOUSE.csv',
#  'APOC2_MOUSE.csv',
#  'APOC3_MOUSE.csv',
#  'APOE_MOUSE.csv',
#  'APOH_MOUSE.csv',
#  'APT_MOUSE.csv',
#  'AQP1_MOUSE.csv',
#  'AR6P1_MOUSE.csv',
#  'ARAF_MOUSE.csv',
#  'ARC1A_MOUSE.csv',
#  'ARC1B_MOUSE.csv',
#  'ARCH_MOUSE.csv',
#  'ARF1_MOUSE.csv',
#  'ARF4_MOUSE.csv',
#  'ARF5_MOUSE.csv',
#  'ARF6_MOUSE.csv',
#  'ARFG2_MOUSE.csv',
#  'ARGI1_MOUSE.csv',
#  'ARHG1_MOUSE.csv',
#  'ARK72_MOUSE.csv',
#  'ARL1_MOUSE.csv',
#  'ARL8A_MOUSE.csv',
#  'ARL8B_MOUSE.csv',
#  'ARLY_MOUSE.csv',
#  'ARMC1_MOUSE.csv',
#  'ARMT1_MOUSE.csv',
#  'ARP2_MOUSE.csv',
#  'ARP3_MOUSE.csv',
#  'ARP5L_MOUSE.csv',
#  'ARPC2_MOUSE.csv',
#  'ARPC3_MOUSE.csv',
#  'ARPC4_MOUSE.csv',
#  'ARPC5_MOUSE.csv',
#  'ARRB1_MOUSE.csv',
#  'ARSA_MOUSE.csv',
#  'ARSB_MOUSE.csv',
#  'ARY2_MOUSE.csv',
#  'AS3MT_MOUSE.csv',
#  'ASAH1_MOUSE.csv',
#  'ASGL1_MOUSE.csv',
#  'ASGR1_MOUSE.csv',
#  'ASGR2_MOUSE.csv',
#  'ASPC1_MOUSE.csv',
#  'ASPD_MOUSE.csv',
#  'ASPG_MOUSE.csv',
#  'ASPH_MOUSE.csv',
#  'ASSY_MOUSE.csv',
#  'AT11C_MOUSE.csv',
#  'AT131_MOUSE.csv',
#  'AT1A1_MOUSE.csv',
#  'AT1B1_MOUSE.csv',
#  'AT1B3_MOUSE.csv',
#  'AT2A2_MOUSE.csv',
#  'AT2L1_MOUSE.csv',
#  'AT5F1_MOUSE.csv',
#  'ATAD1_MOUSE.csv',
#  'ATAD3_MOUSE.csv',
#  'ATG3_MOUSE.csv',
#  'ATG7_MOUSE.csv',
#  'ATLA2_MOUSE.csv',
#  'ATLA3_MOUSE.csv',
#  'ATOX1_MOUSE.csv',
#  'ATP5E_MOUSE.csv',
#  'ATP5H_MOUSE.csv',
#  'ATP5I_MOUSE.csv',
#  'ATP5J_MOUSE.csv',
#  'ATP5L_MOUSE.csv',
#  'ATP68_MOUSE.csv',
#  'ATP6_MOUSE.csv',
#  'ATP8_MOUSE.csv',
#  'ATPA_MOUSE.csv',
#  'ATPB_MOUSE.csv',
#  'ATPD_MOUSE.csv',
#  'ATPG_MOUSE.csv',
#  'ATPK_MOUSE.csv',
#  'ATPMK_MOUSE.csv',
#  'ATPO_MOUSE.csv',
#  'ATTY_MOUSE.csv',
#  'ATX10_MOUSE.csv',
#  'ATX2_MOUSE.csv',
#  'AUHM_MOUSE.csv',
#  'AUP1_MOUSE.csv',
#  'B2L13_MOUSE.csv',
#  'B2MG_MOUSE.csv',
#  'B3AT_MOUSE.csv',
#  'BAAT_MOUSE.csv',
#  'BABA1_MOUSE.csv',
#  'BABA2_MOUSE.csv',
#  'BACH_MOUSE.csv',
#  'BAF_MOUSE.csv',
#  'BAG3_MOUSE.csv',
#  'BAIP2_MOUSE.csv',
#  'BAP31_MOUSE.csv',
#  'BASI_MOUSE.csv',
#  'BCAP_MOUSE.csv',
#  'BCKD_MOUSE.csv',
#  'BDH_MOUSE.csv',
#  'BET1_MOUSE.csv',
#  'BGAL_MOUSE.csv',
#  'BGLR_MOUSE.csv',
#  'BHMT1_MOUSE.csv',
#  'BI1_MOUSE.csv',
#  'BID_MOUSE.csv',
#  'BIEA_MOUSE.csv',
#  'BIG2_MOUSE.csv',
#  'BIP_MOUSE.csv',
#  'BLMH_MOUSE.csv',
#  'BLVRB_MOUSE.csv',
#  'BODG_MOUSE.csv',
#  'BOLA1_MOUSE.csv',
#  'BPHL_MOUSE.csv',
#  'BPNT1_MOUSE.csv',
#  'BRCC3_MOUSE.csv',
#  'BT3L4_MOUSE.csv',
#  'BTD_MOUSE.csv',
#  'BTF3_MOUSE.csv',
#  'BUB3_MOUSE.csv',
#  'BUP1_MOUSE.csv',
#  'BZW1_MOUSE.csv',
#  'C19L1_MOUSE.csv',
#  'C1QBP_MOUSE.csv',
#  'C1TC_MOUSE.csv',
#  'C2CD2_MOUSE.csv',
#  'C4BPA_MOUSE.csv',
#  'C560_MOUSE.csv',
#  'CA050_MOUSE.csv',
#  'CAB39_MOUSE.csv',
#  'CACP_MOUSE.csv',
#  'CADH2_MOUSE.csv',
#  'CADM1_MOUSE.csv',
#  'CAF17_MOUSE.csv',
#  'CAH14_MOUSE.csv',
#  'CAH1_MOUSE.csv',
#  'CAH2_MOUSE.csv',
#  'CAH3_MOUSE.csv',
#  'CAH5A_MOUSE.csv',
#  'CALM1_MOUSE.csv',
#  'CALR_MOUSE.csv',
#  'CALU_MOUSE.csv',
#  'CALX_MOUSE.csv',
#  'CAN1_MOUSE.csv',
#  'CAN2_MOUSE.csv',
#  'CAND1_MOUSE.csv',
#  'CAP1_MOUSE.csv',
#  'CAPR1_MOUSE.csv',
#  'CAPZB_MOUSE.csv',
#  'CASP3_MOUSE.csv',
#  'CASP6_MOUSE.csv',
#  'CASP8_MOUSE.csv',
#  'CATA_MOUSE.csv',
#  'CATB_MOUSE.csv',
#  'CATC_MOUSE.csv',
#  'CATD_MOUSE.csv',
#  'CATF_MOUSE.csv',
#  'CATH_MOUSE.csv',
#  'CATL1_MOUSE.csv',
#  'CATS_MOUSE.csv',
#  'CATZ_MOUSE.csv',
#  'CAVN2_MOUSE.csv',
#  'CAZA1_MOUSE.csv',
#  'CAZA2_MOUSE.csv',
#  'CB072_MOUSE.csv',
#  'CBG_MOUSE.csv',
#  'CBPN_MOUSE.csv',
#  'CBPQ_MOUSE.csv',
#  'CBR1_MOUSE.csv',
#  'CBR4_MOUSE.csv',
#  'CBS_MOUSE.csv',
#  'CBX1_MOUSE.csv',
#  'CC50A_MOUSE.csv',
#  'CCAR1_MOUSE.csv',
#  'CCD25_MOUSE.csv',
#  'CCD47_MOUSE.csv',
#  'CCHL_MOUSE.csv',
#  'CCS_MOUSE.csv',
#  'CD151_MOUSE.csv',
#  'CD166_MOUSE.csv',
#  'CD1D1_MOUSE.csv',
#  'CD2AP_MOUSE.csv',
#  'CD302_MOUSE.csv',
#  'CD36_MOUSE.csv',
#  'CD38_MOUSE.csv',
#  'CD47_MOUSE.csv',
#  'CD68_MOUSE.csv',
#  'CD82_MOUSE.csv',
#  'CDC37_MOUSE.csv',
#  'CDC42_MOUSE.csv',
#  'CDIPT_MOUSE.csv',
#  'CDO1_MOUSE.csv',
#  'CDS2_MOUSE.csv',
#  'CDV3_MOUSE.csv',
#  'CEAM1_MOUSE.csv',
#  'CELF1_MOUSE.csv',
#  'CENPV_MOUSE.csv',
#  'CEPT1_MOUSE.csv',
#  'CERS2_MOUSE.csv',
#  'CERT_MOUSE.csv',
#  'CERU_MOUSE.csv',
#  'CFAB_MOUSE.csv',
#  'CFAH_MOUSE.csv',
#  'CGL_MOUSE.csv',
#  'CH082_MOUSE.csv',
#  'CH10_MOUSE.csv',
#  'CH60_MOUSE.csv',
#  'CHAC2_MOUSE.csv',
#  'CHCH2_MOUSE.csv',
#  'CHD4_MOUSE.csv',
#  'CHDH_MOUSE.csv',
#  'CHIL3_MOUSE.csv',
#  'CHKB_MOUSE.csv',
#  'CHLE_MOUSE.csv',
#  'CHM4B_MOUSE.csv',
#  'CHMP3_MOUSE.csv',
#  'CHMP7_MOUSE.csv',
#  'CHP1_MOUSE.csv',
#  'CHRD1_MOUSE.csv',
#  'CHSP1_MOUSE.csv',
#  'CIA30_MOUSE.csv',
#  'CIDEB_MOUSE.csv',
#  'CING_MOUSE.csv',
#  'CISD1_MOUSE.csv',
#  'CISD2_MOUSE.csv',
#  'CISD3_MOUSE.csv',
#  'CISY_MOUSE.csv',
#  'CK054_MOUSE.csv',
#  'CK5P3_MOUSE.csv',
#  'CKLF6_MOUSE.csv',
#  'CKLF8_MOUSE.csv',
#  'CLC2G_MOUSE.csv',
#  'CLC4F_MOUSE.csv',
#  'CLCA_MOUSE.csv',
#  'CLCB_MOUSE.csv',
#  'CLCC1_MOUSE.csv',
#  'CLD3_MOUSE.csv',
#  'CLH1_MOUSE.csv',
#  'CLIC1_MOUSE.csv',
#  'CLIC4_MOUSE.csv',
#  'CLMN_MOUSE.csv',
#  'CLN8_MOUSE.csv',
#  'CLPB_MOUSE.csv',
#  'CLPP_MOUSE.csv',
#  'CLPT1_MOUSE.csv',
#  'CLPX_MOUSE.csv',
#  'CLUS_MOUSE.csv',
#  'CLU_MOUSE.csv',
#  'CLYBL_MOUSE.csv',
#  'CMAH_MOUSE.csv',
#  'CMBL_MOUSE.csv',
#  'CMC1_MOUSE.csv',
#  'CMC2_MOUSE.csv',
#  'CMLO1_MOUSE.csv',
#  'CMLO5_MOUSE.csv',
#  'CMTD1_MOUSE.csv',
#  'CNBP_MOUSE.csv',
#  'CNDP2_MOUSE.csv',
#  'CNN3_MOUSE.csv',
#  'CNOT1_MOUSE.csv',
#  'CNPY2_MOUSE.csv',
#  'CO1A1_MOUSE.csv',
#  'CO1A2_MOUSE.csv',
#  'CO3_MOUSE.csv',
#  'CO4A1_MOUSE.csv',
#  'CO4A2_MOUSE.csv',
#  'CO4B_MOUSE.csv',
#  'CO5_MOUSE.csv',
#  'CO6A1_MOUSE.csv',
#  'CO6A2_MOUSE.csv',
#  'CO8A_MOUSE.csv',
#  'CO8B_MOUSE.csv',
#  'CO8G_MOUSE.csv',
#  'CO9_MOUSE.csv',
#  'COA6_MOUSE.csv',
#  'COA7_MOUSE.csv',
#  'COASY_MOUSE.csv',
#  'COBL1_MOUSE.csv',
#  'COEA1_MOUSE.csv',
#  'COF1_MOUSE.csv',
#  'COF2_MOUSE.csv',
#  'COIA1_MOUSE.csv',
#  'COMD3_MOUSE.csv',
#  'COMD9_MOUSE.csv',
#  'COMT_MOUSE.csv',
#  'COPA_MOUSE.csv',
#  'COPB2_MOUSE.csv',
#  'COPB_MOUSE.csv',
#  'COPD_MOUSE.csv',
#  'COPE_MOUSE.csv',
#  'COPG1_MOUSE.csv',
#  'COPG2_MOUSE.csv',
#  'COPT1_MOUSE.csv',
#  'COPZ1_MOUSE.csv',
#  'COQ3_MOUSE.csv',
#  'COQ5_MOUSE.csv',
#  'COQ6_MOUSE.csv',
#  'COQ7_MOUSE.csv',
#  'COQ8A_MOUSE.csv',
#  'COQ9_MOUSE.csv',
#  'COR1A_MOUSE.csv',
#  'COR1B_MOUSE.csv',
#  'COR1C_MOUSE.csv',
#  'CORO7_MOUSE.csv',
#  'COTL1_MOUSE.csv',
#  'COX15_MOUSE.csv',
#  'COX1_MOUSE.csv',
#  'COX20_MOUSE.csv',
#  'COX2_MOUSE.csv',
#  'COX3_MOUSE.csv',
#  'COX41_MOUSE.csv',
#  'COX5A_MOUSE.csv',
#  'COX5B_MOUSE.csv',
#  'COX6C_MOUSE.csv',
#  'COX7C_MOUSE.csv',
#  'COX7R_MOUSE.csv',
#  'COX8A_MOUSE.csv',
#  'CP17A_MOUSE.csv',
#  'CP1A2_MOUSE.csv',
#  'CP237_MOUSE.csv',
#  'CP240_MOUSE.csv',
#  'CP254_MOUSE.csv',
#  'CP270_MOUSE.csv',
#  'CP27A_MOUSE.csv',
#  'CP2A5_MOUSE.csv',
#  'CP2AC_MOUSE.csv',
#  'CP2B9_MOUSE.csv',
#  'CP2BA_MOUSE.csv',
#  'CP2BJ_MOUSE.csv',
#  'CP2CN_MOUSE.csv',
#  'CP2CT_MOUSE.csv',
#  'CP2D9_MOUSE.csv',
#  'CP2DA_MOUSE.csv',
#  'CP2DB_MOUSE.csv',
#  'CP2DQ_MOUSE.csv',
#  'CP2E1_MOUSE.csv',
#  'CP2F2_MOUSE.csv',
#  'CP2J5_MOUSE.csv',
#  'CP39A_MOUSE.csv',
#  'CP3AB_MOUSE.csv',
#  'CP3AD_MOUSE.csv',
#  'CP3AP_MOUSE.csv',
#  'CP4AA_MOUSE.csv',
#  'CP4AE_MOUSE.csv',
#  'CP4B1_MOUSE.csv',
#  'CP4CA_MOUSE.csv',
#  'CP4CB_MOUSE.csv',
#  'CP4FE_MOUSE.csv',
#  'CP4V2_MOUSE.csv',
#  'CP51A_MOUSE.csv',
#  'CP7A1_MOUSE.csv',
#  'CP7B1_MOUSE.csv',
#  'CP8B1_MOUSE.csv',
#  'CPIN1_MOUSE.csv',
#  'CPNE1_MOUSE.csv',
#  'CPNE3_MOUSE.csv',
#  'CPNS1_MOUSE.csv',
#  'CPPED_MOUSE.csv',
#  'CPSF2_MOUSE.csv',
#  'CPSF3_MOUSE.csv',
#  'CPSF5_MOUSE.csv',
#  'CPSF6_MOUSE.csv',
#  'CPSM_MOUSE.csv',
#  'CPT1A_MOUSE.csv',
#  'CPT2_MOUSE.csv',
#  'CR1L_MOUSE.csv',
#  'CRADD_MOUSE.csv',
#  'CREG1_MOUSE.csv',
#  'CREL1_MOUSE.csv',
#  'CREL2_MOUSE.csv',
#  'CRIP2_MOUSE.csv',
#  'CRKL_MOUSE.csv',
#  'CRK_MOUSE.csv',
#  'CRYL1_MOUSE.csv',
#  'CSAD_MOUSE.csv',
#  'CSDE1_MOUSE.csv',
#  'CSK21_MOUSE.csv',
#  'CSK22_MOUSE.csv',
#  'CSK2B_MOUSE.csv',
#  'CSK_MOUSE.csv',
#  'CSN1_MOUSE.csv',
#  'CSN2_MOUSE.csv',
#  'CSN3_MOUSE.csv',
#  'CSN4_MOUSE.csv',
#  'CSN5_MOUSE.csv',
#  'CSN6_MOUSE.csv',
#  'CSN7A_MOUSE.csv',
#  'CSN8_MOUSE.csv',
#  'CSRP3_MOUSE.csv',
#  'CSTFT_MOUSE.csv',
#  'CTBL1_MOUSE.csv',
#  'CTNA1_MOUSE.csv',
#  'CTNA2_MOUSE.csv',
#  'CTNB1_MOUSE.csv',
#  'CTND1_MOUSE.csv',
#  'CTR2_MOUSE.csv',
#  'CUL1_MOUSE.csv',
#  'CUL2_MOUSE.csv',
#  'CUL3_MOUSE.csv',
#  'CUL4A_MOUSE.csv',
#  'CUL4B_MOUSE.csv',
#  'CUL5_MOUSE.csv',
#  'CUTA_MOUSE.csv',
#  'CUTC_MOUSE.csv',
#  'CX6A1_MOUSE.csv',
#  'CX6B1_MOUSE.csv',
#  'CX7A1_MOUSE.csv',
#  'CX7A2_MOUSE.csv',
#  'CXAR_MOUSE.csv',
#  'CXB1_MOUSE.csv',
#  'CXB2_MOUSE.csv',
#  'CY1_MOUSE.csv',
#  'CY250_MOUSE.csv',
#  'CYB5B_MOUSE.csv',
#  'CYB5_MOUSE.csv',
#  'CYBC1_MOUSE.csv',
#  'CYBP_MOUSE.csv',
#  'CYB_MOUSE.csv',
#  'CYC_MOUSE.csv',
#  'CYFP1_MOUSE.csv',
#  'CYTB_MOUSE.csv',
#  'D19L1_MOUSE.csv',
#  'D39U1_MOUSE.csv',
#  'DAZP1_MOUSE.csv',
#  'DBNL_MOUSE.csv',
#  'DC1I2_MOUSE.csv',
#  'DC1L1_MOUSE.csv',
#  'DCA11_MOUSE.csv',
#  'DCAF8_MOUSE.csv',
#  'DCAKD_MOUSE.csv',
#  'DCMC_MOUSE.csv',
#  'DCPS_MOUSE.csv',
#  'DCTN1_MOUSE.csv',
#  'DCTN2_MOUSE.csv',
#  'DCUP_MOUSE.csv',
#  'DCXR_MOUSE.csv',
#  'DD19A_MOUSE.csv',
#  'DDAH1_MOUSE.csv',
#  'DDB1_MOUSE.csv',
#  'DDC_MOUSE.csv',
#  'DDI2_MOUSE.csv',
#  'DDRGK_MOUSE.csv',
#  'DDX17_MOUSE.csv',
#  'DDX1_MOUSE.csv',
#  'DDX21_MOUSE.csv',
#  'DDX3X_MOUSE.csv',
#  'DDX3Y_MOUSE.csv',
#  'DDX58_MOUSE.csv',
#  'DDX5_MOUSE.csv',
#  'DDX6_MOUSE.csv',
#  'DECR2_MOUSE.csv',
#  'DECR_MOUSE.csv',
#  'DEK_MOUSE.csv',
#  'DEOC_MOUSE.csv',
#  'DERL1_MOUSE.csv',
#  'DESM_MOUSE.csv',
#  'DESP_MOUSE.csv',
#  'DEST_MOUSE.csv',
#  'DGAT1_MOUSE.csv',
#  'DGUOK_MOUSE.csv',
#  'DHB11_MOUSE.csv',
#  'DHB12_MOUSE.csv',
#  'DHB13_MOUSE.csv',
#  'DHB2_MOUSE.csv',
#  'DHB4_MOUSE.csv',
#  'DHB5_MOUSE.csv',
#  'DHB7_MOUSE.csv',
#  'DHB8_MOUSE.csv',
#  'DHC24_MOUSE.csv',
#  'DHCR7_MOUSE.csv',
#  'DHDH_MOUSE.csv',
#  'DHE3_MOUSE.csv',
#  'DHI1_MOUSE.csv',
#  'DHPR_MOUSE.csv',
#  'DHR11_MOUSE.csv',
#  'DHRS1_MOUSE.csv',
#  'DHRS4_MOUSE.csv',
#  'DHRS7_MOUSE.csv',
#  'DHSD_MOUSE.csv',
#  'DHSO_MOUSE.csv',
#  'DHTK1_MOUSE.csv',
#  'DHX15_MOUSE.csv',
#  'DHX30_MOUSE.csv',
#  'DHX32_MOUSE.csv',
#  'DHX9_MOUSE.csv',
#  'DIAP1_MOUSE.csv',
#  'DIC_MOUSE.csv',
#  'DJB11_MOUSE.csv',
#  'DJB12_MOUSE.csv',
#  'DJC11_MOUSE.csv',
#  'DKC1_MOUSE.csv',
#  'DLDH_MOUSE.csv',
#  'DLG1_MOUSE.csv',
#  'DLRB1_MOUSE.csv',
#  'DMD_MOUSE.csv',
#  'DNJA1_MOUSE.csv',
#  'DNJA2_MOUSE.csv',
#  'DNJA3_MOUSE.csv',
#  'DNJB1_MOUSE.csv',
#  'DNJB2_MOUSE.csv',
#  'DNJB4_MOUSE.csv',
#  'DNJB6_MOUSE.csv',
#  'DNJC3_MOUSE.csv',
#  'DNM1L_MOUSE.csv',
#  'DNPEP_MOUSE.csv',
#  'DOLK_MOUSE.csv',
#  'DOPD_MOUSE.csv',
#  'DOPP1_MOUSE.csv',
#  'DPEP3_MOUSE.csv',
#  'DPM3_MOUSE.csv',
#  'DPP2_MOUSE.csv',
#  'DPP3_MOUSE.csv',
#  'DPP4_MOUSE.csv',
#  'DPP9_MOUSE.csv',
#  'DPTOR_MOUSE.csv',
#  'DPY30_MOUSE.csv',
#  'DPYD_MOUSE.csv',
#  'DPYL2_MOUSE.csv',
#  'DPYS_MOUSE.csv',
#  'DRG1_MOUSE.csv',
#  'DRS7B_MOUSE.csv',
#  'DSC2_MOUSE.csv',
#  'DSG2_MOUSE.csv',
#  'DTD2_MOUSE.csv',
#  'DTX3L_MOUSE.csv',
#  'DUS3_MOUSE.csv',
#  'DX39A_MOUSE.csv',
#  'DX39B_MOUSE.csv',
#  'DYHC1_MOUSE.csv',
#  'DYL1_MOUSE.csv',
#  'DYN2_MOUSE.csv',
#  'DYR_MOUSE.csv',
#  'E41L2_MOUSE.csv',
#  'E41L5_MOUSE.csv',
#  'EBP_MOUSE.csv',
#  'ECH1_MOUSE.csv',
#  'ECHA_MOUSE.csv',
#  'ECHB_MOUSE.csv',
#  'ECHD1_MOUSE.csv',
#  'ECHD2_MOUSE.csv',
#  'ECHD3_MOUSE.csv',
#  'ECHM_MOUSE.csv',
#  'ECHP_MOUSE.csv',
#  'ECI1_MOUSE.csv',
#  'ECI2_MOUSE.csv',
#  'ECM29_MOUSE.csv',
#  'ECSIT_MOUSE.csv',
#  'EDEM1_MOUSE.csv',
#  'EEA1_MOUSE.csv',
#  'EF1A1_MOUSE.csv',
#  'EF1B_MOUSE.csv',
#  'EF1D_MOUSE.csv',
#  'EF1G_MOUSE.csv',
#  'EF2_MOUSE.csv',
#  'EFGM_MOUSE.csv',
#  'EFHD2_MOUSE.csv',
#  'EFL1_MOUSE.csv',
#  'EFTS_MOUSE.csv',
#  'EFTU_MOUSE.csv',
#  'EGFR_MOUSE.csv',
#  'EHD1_MOUSE.csv',
#  'EHD3_MOUSE.csv',
#  'EI2BB_MOUSE.csv',
#  'EI2BE_MOUSE.csv',
#  'EI3JA_MOUSE.csv',
#  'EIF1_MOUSE.csv',
#  'EIF2A_MOUSE.csv',
#  'EIF3A_MOUSE.csv',
#  'EIF3B_MOUSE.csv',
#  'EIF3C_MOUSE.csv',
#  'EIF3D_MOUSE.csv',
#  'EIF3E_MOUSE.csv',
#  'EIF3F_MOUSE.csv',
#  'EIF3G_MOUSE.csv',
#  'EIF3H_MOUSE.csv',
#  'EIF3I_MOUSE.csv',
#  'EIF3K_MOUSE.csv',
#  'EIF3L_MOUSE.csv',
#  'EIF3M_MOUSE.csv',
#  'EKI2_MOUSE.csv',
#  'ELAV1_MOUSE.csv',
#  'ELOB_MOUSE.csv',
#  'ELOC_MOUSE.csv',
#  'ELOV2_MOUSE.csv',
#  'EM55_MOUSE.csv',
#  'EMAL2_MOUSE.csv',
#  'EMC10_MOUSE.csv',
#  'EMC1_MOUSE.csv',
#  'EMC2_MOUSE.csv',
#  'EMC3_MOUSE.csv',
#  'EMC7_MOUSE.csv',
#  'EMC8_MOUSE.csv',
#  'ENOA_MOUSE.csv',
#  'ENPL_MOUSE.csv',
#  'ENPP1_MOUSE.csv',
#  'ENPP3_MOUSE.csv',
#  'ENSA_MOUSE.csv',
#  'ENTP5_MOUSE.csv',
#  'EPB41_MOUSE.csv',
#  'EPIPL_MOUSE.csv',
#  'EPN1_MOUSE.csv',
#  'EPN4_MOUSE.csv',
#  'EPS15_MOUSE.csv',
#  'ERAP1_MOUSE.csv',
#  'ERD21_MOUSE.csv',
#  'ERD22_MOUSE.csv',
#  'ERF1_MOUSE.csv',
#  'ERF3A_MOUSE.csv',
#  'ERG24_MOUSE.csv',
#  'ERG28_MOUSE.csv',
#  'ERGI1_MOUSE.csv',
#  'ERH_MOUSE.csv',
#  'ERLEC_MOUSE.csv',
#  'ERLN2_MOUSE.csv',
#  'ERO1A_MOUSE.csv',
#  'ERO1B_MOUSE.csv',
#  'ERP29_MOUSE.csv',
#  'ERP44_MOUSE.csv',
#  'ES8L2_MOUSE.csv',
#  'EST1C_MOUSE.csv',
#  'EST1D_MOUSE.csv',
#  'EST1E_MOUSE.csv',
#  'EST1F_MOUSE.csv',
#  'EST1_MOUSE.csv',
#  'EST2A_MOUSE.csv',
#  'EST2C_MOUSE.csv',
#  'EST2E_MOUSE.csv',
#  'EST3A_MOUSE.csv',
#  'EST3B_MOUSE.csv',
#  'ESTD_MOUSE.csv',
#  'ESYT1_MOUSE.csv',
#  'ETFA_MOUSE.csv',
#  'ETFB_MOUSE.csv',
#  'ETFD_MOUSE.csv',
#  'ETHE1_MOUSE.csv',
#  'EWS_MOUSE.csv',
#  'F10A1_MOUSE.csv',
#  'F1142_MOUSE.csv',
#  'F120A_MOUSE.csv',
#  'F136A_MOUSE.csv',
#  'F162A_MOUSE.csv',
#  'F16P1_MOUSE.csv',
#  'F210A_MOUSE.csv',
#  'F210B_MOUSE.csv',
#  'F234A_MOUSE.csv',
#  'F261_MOUSE.csv',
#  'FA98A_MOUSE.csv',
#  'FA98B_MOUSE.csv',
#  'FAAA_MOUSE.csv',
#  'FAAH1_MOUSE.csv',
#  'FABD_MOUSE.csv',
#  'FABP4_MOUSE.csv',
#  'FABP5_MOUSE.csv',
#  'FABPI_MOUSE.csv',
#  'FABPL_MOUSE.csv',
#  'FACE1_MOUSE.csv',
#  'FAD1_MOUSE.csv',
#  'FADS1_MOUSE.csv',
#  'FADS2_MOUSE.csv',
#  'FAF1_MOUSE.csv',
#  'FAF2_MOUSE.csv',
#  'FAHD1_MOUSE.csv',
#  'FAHD2_MOUSE.csv',
#  'FARP1_MOUSE.csv',
#  'FAS_MOUSE.csv',
#  'FBRL_MOUSE.csv',
#  'FBX3_MOUSE.csv',
#  'FBX6_MOUSE.csv',
#  'FCAMR_MOUSE.csv',
#  'FCGR2_MOUSE.csv',
#  'FCL_MOUSE.csv',
#  'FERM2_MOUSE.csv',
#  'FETUA_MOUSE.csv',
#  'FETUB_MOUSE.csv',
#  'FGGY_MOUSE.csv',
#  'FIBA_MOUSE.csv',
#  'FIBB_MOUSE.csv',
#  'FIBG_MOUSE.csv',
#  'FINC_MOUSE.csv',
#  'FIS1_MOUSE.csv',
#  'FKB11_MOUSE.csv',
#  'FKB15_MOUSE.csv',
#  'FKB1A_MOUSE.csv',
#  'FKBP2_MOUSE.csv',
#  'FKBP3_MOUSE.csv',
#  'FKBP4_MOUSE.csv',
#  'FKBP5_MOUSE.csv',
#  'FKBP8_MOUSE.csv',
#  'FLII_MOUSE.csv',
#  'FLNA_MOUSE.csv',
#  'FLNB_MOUSE.csv',
#  'FLOT1_MOUSE.csv',
#  'FLOT2_MOUSE.csv',
#  'FMO1_MOUSE.csv',
#  'FMO4_MOUSE.csv',
#  'FMO5_MOUSE.csv',
#  'FN3K_MOUSE.csv',
#  'FNTA_MOUSE.csv',
#  'FPPS_MOUSE.csv',
#  'FRDA_MOUSE.csv',
#  'FRIH_MOUSE.csv',
#  'FRIL1_MOUSE.csv',
#  'FSCN1_MOUSE.csv',
#  'FSIP2_MOUSE.csv',
#  'FTCD_MOUSE.csv',
#  'FUBP1_MOUSE.csv',
#  'FUBP2_MOUSE.csv',
#  'FUCM_MOUSE.csv',
#  'FUMH_MOUSE.csv',
#  'FUS_MOUSE.csv',
#  'FXR1_MOUSE.csv',
#  'FYB2_MOUSE.csv',
#  'G3BP1_MOUSE.csv',
#  'G3BP2_MOUSE.csv',
#  'G3P_MOUSE.csv',
#  'G6PC1_MOUSE.csv',
#  'G6PD1_MOUSE.csv',
#  'G6PE_MOUSE.csv',
#  'G6PI_MOUSE.csv',
#  'GABT_MOUSE.csv',
#  'GAL3A_MOUSE.csv',
#  'GALD1_MOUSE.csv',
#  'GALE_MOUSE.csv',
#  'GALK1_MOUSE.csv',
#  'GALK2_MOUSE.csv',
#  'GALM_MOUSE.csv',
#  'GALNS_MOUSE.csv',
#  'GALT_MOUSE.csv',
#  'GAMT_MOUSE.csv',
#  'GANAB_MOUSE.csv',
#  'GAR1_MOUSE.csv',
#  'GARS_MOUSE.csv',
#  'GAS2_MOUSE.csv',
#  'GATM_MOUSE.csv',
#  'GBB1_MOUSE.csv',
#  'GBB2_MOUSE.csv',
#  'GBG12_MOUSE.csv',
#  'GBRAP_MOUSE.csv',
#  'GCAB_MOUSE.csv',
#  'GCDH_MOUSE.csv',
#  'GCH1_MOUSE.csv',
#  'GCKR_MOUSE.csv',
#  'GCN1_MOUSE.csv',
#  'GCP60_MOUSE.csv',
#  'GCSH_MOUSE.csv',
#  'GCSP_MOUSE.csv',
#  'GCST_MOUSE.csv',
#  'GDC_MOUSE.csv',
#  'GDIA_MOUSE.csv',
#  'GDIB_MOUSE.csv',
#  'GDIR1_MOUSE.csv',
#  'GELS_MOUSE.csv',
#  'GEPH_MOUSE.csv',
#  'GET3_MOUSE.csv',
#  'GFRP_MOUSE.csv',
#  'GGACT_MOUSE.csv',
#  'GGCT_MOUSE.csv',
#  'GGLO_MOUSE.csv',
#  'GHC1_MOUSE.csv',
#  'GHITM_MOUSE.csv',
#  'GIMA4_MOUSE.csv',
#  'GLCM_MOUSE.csv',
#  'GLCNE_MOUSE.csv',
#  'GLCTK_MOUSE.csv',
#  'GLGB_MOUSE.csv',
#  'GLNA_MOUSE.csv',
#  'GLO2_MOUSE.csv',
#  'GLOD4_MOUSE.csv',
#  'GLP3L_MOUSE.csv',
#  'GLPK_MOUSE.csv',
#  'GLRX1_MOUSE.csv',
#  'GLRX3_MOUSE.csv',
#  'GLRX5_MOUSE.csv',
#  'GLSL_MOUSE.csv',
#  'GLTD2_MOUSE.csv',
#  'GLU2B_MOUSE.csv',
#  'GLUCM_MOUSE.csv',
#  'GLYAL_MOUSE.csv',
#  'GLYAT_MOUSE.csv',
#  'GLYC_MOUSE.csv',
#  'GLYG_MOUSE.csv',
#  'GLYM_MOUSE.csv',
#  'GMFB_MOUSE.csv',
#  'GMPPA_MOUSE.csv',
#  'GMPPB_MOUSE.csv',
#  'GMPR2_MOUSE.csv',
#  'GNA11_MOUSE.csv',
#  'GNA1_MOUSE.csv',
#  'GNAI2_MOUSE.csv',
#  'GNAI3_MOUSE.csv',
#  'GNAQ_MOUSE.csv',
#  ...]

# %%
path= '../data/no_alignment/'+organ
filelist=os.listdir(path)
filelist.remove("compare.csv")
proteinlist= []
for p in filelist:
    if p.endswith(".csv"):
        proteinlist.append(p)            

data=pd.DataFrame()
for  p in proteinlist:
    d=pd.read_csv(os.path.join(path,p))
    d["Protein"]=p.replace('.csv','')
    data=pd.concat([data,d])       

    data["diff"]= abs(data["old_Rsquared"] - data["new_Rsquared"])    
# data=data[data.NDP >=4]
print(data.shape)
# Out:
# (27307, 31)

# %%
data_noalign=data
data_noalign.head()
# Out:
#    proteinName   peptideSeq  charge  old_Rsquared  new_Rsquared  NDP  \
# 0  1433B_MOUSE     NLLSVAYK       2      0.967023      0.982095    7
# 1  1433B_MOUSE    EMQPTHPIR       3      0.976155      0.993823    6
# 2  1433B_MOUSE   DSTLIMQLLR       2      0.985986      0.997529   12
# 3  1433B_MOUSE  YLSEVASGENK       2      0.986787      0.996046   12
# 4  1433B_MOUSE   DSTLImQLLR       2     -0.132288      0.291445   12
#
#    rateconstant     sigma     Abundance  MassToCharge  ...  lowerci_old  \
# 0       0.16249  0.015089  1.432731e+09     454.26599  ...     0.126805
# 1       0.13397  0.011496  1.813278e+08     370.19043  ...     0.099607
# 2       0.19307  0.009791  1.747584e+09     595.33411  ...     0.174313
# 3       0.23813  0.011572  1.513652e+08     598.79327  ...     0.211593
# 4       0.10303  0.026401  4.965206e+07     603.33154  ...     0.039029
#
#    upperci_old  sigma_old  lowerci_new upperci_new  sigma_new old_pearson  \
# 0     0.198175   0.014584     0.136035    0.188945   0.010812    0.993085
# 1     0.168333   0.013368     0.115684    0.152256   0.007114    0.993588
# 2     0.211827   0.008522     0.185113    0.201027   0.003615    0.994336
# 3     0.264667   0.012057     0.223234    0.253026   0.006768    0.997019
# 4     0.167031   0.029078     0.045577    0.160483   0.026103    0.743668
#
#   new_pearson      Protein      diff
# 0    0.995694  1433B_MOUSE  0.015072
# 1    0.998221  1433B_MOUSE  0.017668
# 2    0.999524  1433B_MOUSE  0.011544
# 3    0.998608  1433B_MOUSE  0.009259
# 4    0.830570  1433B_MOUSE  0.423734
#
# [5 rows x 31 columns]

# %%
print("Rsquared >= 95 \t Original d2ome =",data[data.old_Rsquared>=0.95].shape[0])
print("Rsquared >= 90 \t Original d2ome =",data[data.old_Rsquared>=0.9].shape[0])
print("Rsquared >= 80 \t Original d2ome =", data[data.old_Rsquared>=0.8].shape[0])
print("Rsquared >= 75 \t Original d2ome =",data[data.old_Rsquared>=0.75].shape[0])
print("Rsquared <= 75 \t Original d2ome =",data[data.old_Rsquared<=0.75].shape[0])
# Out:
# Rsquared >= 95 	 Original d2ome = 7042
# Rsquared >= 90 	 Original d2ome = 10407
# Rsquared >= 80 	 Original d2ome = 13568
# Rsquared >= 75 	 Original d2ome = 14481
# Rsquared <= 75 	 Original d2ome = 12376

# %%
no_alignmentdata=[data[data.old_Rsquared>=0.95].shape[0],data[data.old_Rsquared>=0.9].shape[0], data[data.old_Rsquared>=0.8].shape[0],
data[data.old_Rsquared>=0.75].shape[0],data[data.old_Rsquared<=0.75].shape[0]]

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(9,6))
bar_width = 0.25
index=np.array([0,1,2,3])

# '#3CAEA3','#F6D55C','#ED553B','#20639b'

plt.bar(index,no_alignmentdata[:-1],bar_width, label= "With out Alignment" ,color='#ED553B') #ED553B
# plt.bar(index+bar_width,noAlin,bar_width, label= "With Zero Ionscore",color='#F6D55C')
plt.bar(index+bar_width,alignmentdata[:-1],bar_width, label="With Alignment",color='#20639b')

plt.xticks([0,1,2,3],[r'$R^2$ ≥ 95',r'$R^2$ ≥ 90',r'$R^2$ ≥ 80',r'$R^2$ ≥ 75'])
plt.legend()

# plt.savefig(f"{organ}.jpeg",dpi=900, bbox_inches = "tight")

# %%
# data_align.columns

# %%
# temp_merge

# %%
temp_align=data_align.groupby("NDP")["peptideSeq"].count().reset_index()
temp_noalign=data_noalign.groupby("NDP")["peptideSeq"].count()

temp_merge=temp_align.merge(temp_noalign,on="NDP")
temp_merge.NDP=temp_merge.NDP.astype(int)
temp_merge.set_index("NDP")
temp_merge=temp_merge[temp_merge.NDP>=2]
temp_merge=temp_merge[["peptideSeq_x","peptideSeq_y"]]
temp_merge.columns=["With Alignment","Without Alignment"]
# ======================= Plot =======================
plt.rc('font', size=14) 
temp_merge[["Without Alignment","With Alignment"]].plot(kind="bar",width=0.9,rot=0,figsize=(9,6),
                                                        color=["#ED553B","#20639b"])
plt.ylabel("Number of peptides")
plt.xlabel("Number of data points")

plt.savefig(f"NDP_{organ}_all.jpeg",dpi=900, bbox_inches = "tight")

# %%
# temp_align=data_align[data_align.old_Rsquared>=0.75].groupby("NDP")["peptideSeq"].count().reset_index()
# temp_noalign=data_noalign[data_noalign.old_Rsquared>=0.75].groupby("NDP")["peptideSeq"].count()
# temp_merge=temp_align.merge(temp_noalign,on="NDP")
# temp_merge.NDP=temp_merge.NDP.astype(int)
# temp_merge.set_index("NDP")
# temp_merge=temp_merge[temp_merge.NDP>=2]
# temp_merge=temp_merge[["peptideSeq_x","peptideSeq_y"]]
# temp_merge.columns=["With Alignment","Without Alignment"]

# # ====================================================
# # ======================= Plot =======================
# wa=int(temp_merge[["With Alignment"]].sum())
# woa=int(temp_merge[["Without Alignment"]].sum())

# plt.rc('font', size=14) 
# g=temp_merge[["Without Alignment","With Alignment"]].plot(kind="bar",width=0.9,rot=0,figsize=(9,6),
#                                                         color=["#ED553B","#20639b"])
# plt.ylabel("Number of peptides")
# plt.xlabel("Number of data points")
# plt.title(f"Without Alignment = {woa}, With Alignment = {wa}")
# g.set_xticklabels(range(2,13))
# # plt.savefig(f"NDP_liver.jpeg",dpi=900, bbox_inches = "tight")

# %%
rsq=[0.95,0.9,0.8,0.75]

for r in rsq:
    temp_align=data_align[data_align.old_Rsquared>=r].groupby("NDP")["peptideSeq"].count().reset_index()
    temp_noalign=data_noalign[data_noalign.old_Rsquared>=r].groupby("NDP")["peptideSeq"].count()
    temp_merge=temp_align.merge(temp_noalign,on="NDP")
    temp_merge.NDP=temp_merge.NDP.astype(int)
    temp_merge.set_index("NDP")
    temp_merge=temp_merge[temp_merge.NDP>=2]
    temp_merge=temp_merge[["peptideSeq_x","peptideSeq_y"]]
    temp_merge.columns=["With Alignment","Without Alignment"]

    # ====================================================
    # ======================= Plot =======================
    wa=int(temp_merge[["With Alignment"]].sum())
    woa=int(temp_merge[["Without Alignment"]].sum())
    
    plt.rc('font', size=14) 
    g=temp_merge[["Without Alignment","With Alignment"]].plot(kind="bar",width=0.9,rot=0,figsize=(9,6),
                                                            color=["#ED553B","#20639b"])
    plt.ylabel("Number of peptides")
    plt.xlabel("Number of data points")
    plt.title("$R{^2}$"+f" ≥ {r}, Without Alignment = {woa}, With Alignment = {wa}")
    g.set_xticklabels(range(2,13))

    plt.savefig(f"NDP_{organ}_{r}.jpeg",dpi=900, bbox_inches = "tight")

# %%
# print(temp_merge[["With Alignment"]].sum())
# print(temp_merge[["Without Alignment"]].sum())

# %%
data_align.shape
# Out:
# (27307, 31)

# %%
data_noalign.shape
# Out:
# (27307, 31)

# %%
data_align[data_align.NDP>=4].sigma_old.describe()
# Out:
# count    26453.000000
# mean         0.084001
# std          0.277272
# min          0.000264
# 25%          0.009699
# 50%          0.018186
# 75%          0.041326
# max          9.250002
# Name: sigma_old, dtype: float64

# %%
data_noalign[data_noalign.NDP>=4].sigma_old.describe()
# Out:
# count    1.988500e+04
# mean     1.132022e+02
# std      1.554711e+04
# min      2.636674e-04
# 25%      1.135583e-02
# 50%      2.225005e-02
# 75%      4.933474e-02
# max      2.191635e+06
# Name: sigma_old, dtype: float64

# %%
# import seaborn as sns
# sns.distplot(data_noalign[(data_noalign.NDP>=4) & (data_noalign.sigma_old < 1)].sigma_old.astype(float) , 
#               hist=False, kde=True, bins=5000, 
#              hist_kws={'edgecolor':'black'},
#              kde_kws={'linewidth': 1,"bw_adjust":0.6},label="Actual")

# sns.distplot(data_align[(data_align.NDP>=4) & (data_align.sigma_old < 1)].sigma_old.astype(float) , 
#               hist=False, kde=True, bins=5000, 
#              hist_kws={'edgecolor':'black'},
#              kde_kws={'linewidth': 1,"bw_adjust":0.6},label="Actual")

# %%
# data_noalign[data_noalign.sigma_old<0]
np.std(data_noalign[data_noalign.NDP>=4].sigma_old)
# Out:
# 15546.718893550382
