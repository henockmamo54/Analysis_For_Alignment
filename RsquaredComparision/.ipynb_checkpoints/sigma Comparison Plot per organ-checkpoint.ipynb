# %%
import os
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
# organ = "liver"
# organ = "heart"
organ = "muscle"
# organ = "kidney"

# %% [markdown]
# Load data
# ===

# %%
path= '../data/alignment/'+organ
filelist=os.listdir(path)
filelist.remove("compare.csv")
proteinlist= []
for p in filelist:
    if p.endswith(".csv"):
        proteinlist.append(p)            

data=pd.DataFrame()
for  p in proteinlist:
    d=pd.read_csv(os.path.join(path,p))
    d["Protein"]=p.replace('.csv','')
    data=pd.concat([data,d])       

    data["diff"]= abs(data["old_Rsquared"] - data["new_Rsquared"])    

print(data.shape)
data=data[data.NDP >=4]

data=data[data.rateconstant>0.01]
data=data[data.rateconstant<1.5]
data=data[data.old_Rsquared>=0.80]
print(data.shape)

# %%
align_data=data[['proteinName', 'peptideSeq', 'charge','sigma','NDP','RMSE']]
align_data.head()

# %%
path= '../data/no_alignment/'+organ
filelist=os.listdir(path)
filelist.remove("compare.csv")
proteinlist= []
for p in filelist:
    if p.endswith(".csv"):
        proteinlist.append(p)            

data=pd.DataFrame()
for  p in proteinlist:
    d=pd.read_csv(os.path.join(path,p))
    d["Protein"]=p.replace('.csv','')
    data=pd.concat([data,d])       

    data["diff"]= abs(data["old_Rsquared"] - data["new_Rsquared"])    

print(data.shape)
data=data[data.NDP >=4]
data=data[data.NDP !=12]

print(data.shape)
# Out:
# (10163, 31)
# (7789, 31)

# %%
noalign_data=data[['proteinName', 'peptideSeq', 'charge','sigma','NDP','RMSE']]
noalign_data.head()
# Out:
#    proteinName     peptideSeq  charge     sigma  NDP      RMSE
# 0  1433E_MOUSE       NLLSVAYK       2  0.001598    7  0.007402
# 1  1433E_MOUSE      YDEMVESMK       2  0.004657   11  0.031194
# 2  1433E_MOUSE     DSTLIMQLLR       2  0.001311    9  0.007244
# 3  1433E_MOUSE    YLAEFATGNDR       2  0.001358   11  0.010380
# 4  1433E_MOUSE  VAGMDVELTVEER       2  0.012983    7  0.039558

# %%
merged=align_data.merge(noalign_data, on=['proteinName', 'peptideSeq', 'charge'])
merged=merged.sort_values(by="sigma_y")
merged.tail(20)
# Out:
#       proteinName               peptideSeq  charge   sigma_x  NDP_x    RMSE_x  \
# 1154  NDRG2_MOUSE   GIIQHAPNLENIELYWNSYNNR       3  0.008858     12  0.014325
# 181   ALDH2_MOUSE        VAEQTPLTALYVANLIK       2  0.010960     11  0.021757
# 167    ALBU_MOUSE          TVMDDFAQFLDTccK       2  0.016773     12  0.019351
# 151    ALBU_MOUSE               LVQEVTDFAK       2  0.015406     12  0.018571
# 2041   TRFE_MOUSE              cDEWSIISEGK       2  0.019394     12  0.014557
# 1262  PDLI3_MOUSE         GYFFVEGELYcETHAR       3  0.015385     12  0.018183
# 2049   TRFE_MOUSE       DFAScHLAQAPNHVVVSR       4  0.019276     12  0.018480
# 1511  SPA3K_MOUSE  AVLDVAETGTEAAAATGVIGGIR       2  0.037117      8  0.020521
# 2046   TRFE_MOUSE            KPVDQYEDcYLAR       3  0.019247     12  0.018938
# 2043   TRFE_MOUSE            SKDFQLFSSPLGK       3  0.023308     12  0.024421
# 401    CD36_MOUSE          QFWIFDVQNPDDVAK       2  0.012986     10  0.017108
# 451   DDX3L_MOUSE             SFLLDLLNATGK       2  0.017163     10  0.014858
# 2047   TRFE_MOUSE          FDEFFSQGcAPGYEK       2  0.018903     12  0.013685
# 161    ALBU_MOUSE            FSALTVDETYVPK       2  0.021471     12  0.020654
# 2040   TRFE_MOUSE              HQTVLDNTEGK       2  0.020731     12  0.020244
# 2038   TRFE_MOUSE                GYYAVAVVK       2  0.024870     12  0.026675
# 665   HSPB7_MOUSE            TLGDAYEFTVDMR       2  0.024137     12  0.022754
# 1509  SPA3K_MOUSE              DLQILAEFHEK       2  0.036351      9  0.022024
# 2045   TRFE_MOUSE            QEDFELLcPDGTR       2  0.045817     12  0.020472
# 1545   TELT_MOUSE                 EETPIQLR       2  0.055744     12  0.026448
#
#        sigma_y  NDP_y    RMSE_y
# 1154  0.015377      6  0.012256
# 181   0.016646      4  0.015855
# 167   0.016773     12  0.019351
# 151   0.017098     10  0.018318
# 2041  0.017900      9  0.012305
# 1262  0.018323      7  0.014837
# 2049  0.018616      6  0.013988
# 1511  0.019164      6  0.010534
# 2046  0.019297      8  0.014526
# 2043  0.019506      6  0.015481
# 401   0.019880      5  0.014756
# 451   0.020062      6  0.014087
# 2047  0.020168      5  0.011593
# 161   0.020955      9  0.019498
# 2040  0.022530      6  0.018637
# 2038  0.024870     12  0.026675
# 665   0.026583      8  0.021770
# 1509  0.037973      5  0.020504
# 2045  0.039739      6  0.017145
# 1545  0.064158      4  0.022905

# %%
plt.scatter(merged.sigma_x,merged.sigma_y,c='k')
plt.plot(merged.sigma_x,merged.sigma_x,c='r')
plt.xlim([0,0.081])
plt.ylim([0,0.081])
plt.xlabel("with Alignment")
plt.ylabel("Without Alignment")
# Out:
# Text(0, 0.5, 'Without Alignment')

# %%
# import seaborn as sns
# # sns.kdeplot(merged.sigma_x)
# # plt.show()
# # sns.kdeplot(merged.sigma_y)

# # plt.hist(merged.sigma_x)
# # plt.show()
# # plt.hist(merged.sigma_y)

# # plt.xlim([-10,1000])
# # plt.ylim([-10,10])

# %%
# merged[["sigma_x","sigma_y"]].describe()

# %%
# ax = sns.boxplot(data=merged[["sigma_x","sigma_y"]], orient="h", palette="cool_r")

# %%
print(merged[merged.sigma_x > merged.sigma_y].shape[0]/merged.shape[0],
      merged[merged.sigma_x == merged.sigma_y].shape[0]/merged.shape[0],
      merged[merged.sigma_x < merged.sigma_y].shape[0]/merged.shape[0])
# Out:
# 0.23704414587332054 0.3920345489443378 0.3709213051823417

# %%
print(merged[merged.sigma_x/(merged.NDP_x**0.5) > merged.sigma_y /(merged.NDP_y**0.5)].shape[0]/merged.shape[0],
      merged[merged.sigma_x/(merged.NDP_x**0.5) == merged.sigma_y/(merged.NDP_y**0.5)].shape[0]/merged.shape[0],
      merged[merged.sigma_x/(merged.NDP_x**0.5) < merged.sigma_y /(merged.NDP_y**0.5)].shape[0]/merged.shape[0])
# Out:
# 0.09213051823416507 0.3920345489443378 0.5158349328214972

# %%
# data.columns
