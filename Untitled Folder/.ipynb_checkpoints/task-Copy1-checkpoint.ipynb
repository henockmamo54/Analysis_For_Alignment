# %%
import os
import pandas as pd
import numpy as np

# %%
filepath="C:\\Users\\hmdebern.UTMB-USERS-M\\Desktop\\human_yeast_data_10\\"
files=os.listdir(filepath)
files=[x for x in files if "YEAST.Quant.csv" in x]
print(len(files))
# Out:
# 399

# %%
TN=0
FN=0
FP=0
TP=0
start=12
ndk=dict()

nonzeropoints=0
elu_window=0

temp_fillalldata=pd.read_csv(filepath+files[files.index('6PGD1_YEAST.Quant.csv') ],header=None,skiprows=2,index_col=False)  
temp_fillalldata.fillna(-500)

for row in range(temp_fillalldata.shape[0]):
    
    expriments=[]
    for i in range(40):
        try:
            expriments.append(list(temp_fillalldata.iloc[row,start +i*16:(start+16)+ i*16].astype('float')))
        except:
            expriments.append([-500]*16)
        if(i>19 and (expriments[-1][1])>0): # check ionscore
            nonzeropoints+=1 # count nonzero ionscore points
            if(sum(expriments[-1][5:11])>0): # to compute elution window
                elu_window=abs(expriments[-1][11]-expriments[-1][12])

    if nonzeropoints >=4:
        for i in range(20):
            temp=expriments[i]
            if(temp[1]==100 or temp[1]==0):#ionscore ==0
                isotopsum=sum(temp[5:11])
                
                if( isotopsum ==0 or isotopsum < 1E5 or abs(temp[11]-temp[12])<= 0.5*elu_window  ): #
                    TN+=1
                elif(isotopsum>0):
                    FP+=1
                    
            elif(temp[1]>=0 and temp[1] != 100 ):
                ndk[i]=ndk.get(i,0)+1

#         for i in range(20,40):
#             temp=expriments[i]
#             if(temp[1]==0): #ionscore ==0
#                 isotopsum=sum(temp[5:11])
#                 if( isotopsum > 0 and isotopsum > 1E5 and abs(temp[11]-temp[12])>= 0.5*elu_window):
#                     TP+=1
#                 elif(isotopsum==0 or isotopsum < 1E5 or abs(temp[11]-temp[12])<= 0.5*elu_window):
#                     FN+=1
print(TN,FP,TP,FN)
print(sum(ndk.values()),str(ndk))
# Out:
# 10 0 0 0
# 2 {9: 2}

# %%
ndk
# Out:
# {9: 2}

# %% [markdown]
# 3. this one
# ===

# %%
TN=0
FN=0
FP=0
TP=0
start=12
ndk=dict()

for f in range(len(files)):#
    try:
        print(f,files[f])
        
        nonzeropoints=0
        elu_window=0

#         temp_fillalldata=pd.read_csv( filepath+files[f],skiprows=3,index_col=False)  
        temp_fillalldata=pd.read_csv(filepath+files[f],header=None,skiprows=2,index_col=False)  
        temp_fillalldata.fillna(-500)

        for row in range(temp_fillalldata.shape[0]):
            #read experiments
            expriments=[]
            for i in range(40):
                try:
                    expriments.append(list(temp_fillalldata.iloc[row,start +i*16:(start+16)+ i*16].astype('float')))
                except:
                    expriments.append([-500]*16)
                
#                 print(row, i,expriments[-1])
                
                if(i>19 and (expriments[-1][1])>0): # check ionscore
                    nonzeropoints+=1 # count nonzero ionscore points
                    if(sum(expriments[-1][5:11])>0): # to compute elution window
                        elu_window=abs(expriments[-1][11]-expriments[-1][12])

            if nonzeropoints >=4:
                for i in range(20):
                    temp=expriments[i]
                     
                    if(temp[1]==100 or temp[1]==0):#ionscore ==0
                        isotopsum=sum(temp[5:11])
                        if( isotopsum ==0 ):#or isotopsum < 1E5 or abs(temp[11]-temp[12])<= 0.5*elu_window
                            TN+=1
                        elif(isotopsum>0):
                            FP+=1
                    
                    elif(temp[1]>=0 and temp[1] != 100 ):
                        ndk[i]=ndk.get(i,0)+1

                for i in range(20,40):
                    temp=expriments[i]
                    if(temp[1]==0): #ionscore ==0
                        isotopsum=sum(temp[5:11])
                        if( isotopsum > 0 and isotopsum > 1E5 and abs(temp[11]-temp[12])>= 0.5*elu_window):
                            TP+=1
                        elif(isotopsum==0 or isotopsum < 1E5 or abs(temp[11]-temp[12])<= 0.5*elu_window):
                            FN+=1

        print(TN,FP,TP,FN)
    except:
        print("E",files[f])
# Out:
# 0 6PGD1_YEAST.Quant.csv
# 8 2 41 6
# 1 AATC_YEAST.Quant.csv
# 8 2 61 6
# 2 ABF2_YEAST.Quant.csv
# 8 2 61 6
# 3 ABP1_YEAST.Quant.csv
# 8 2 90 16
# 4 ACAC_YEAST.Quant.csv
# 8 2 93 16
# 5 ACBP_YEAST.Quant.csv
# 8 2 95 16
# 6 ACEA_YEAST.Quant.csv
# 8 2 132 39
# 7 ACH1_YEAST.Quant.csv
# 8 2 166 43
# 8 ACON_YEAST.Quant.csv
# 8 2 223 52
# 9 ACS1_YEAST.Quant.csv
# 8 2 242 70
# 10 ACT_YEAST.Quant.csv
# 8 2 282 76
# 11 ADH1_YEAST.Quant.csv
# 8 2 303 114
# 12 ADH2_YEAST.Quant.csv
# 8 2 324 117
# 13 ADH3_YEAST.Quant.csv
# 8 2 327 122
# 14 ADK_YEAST.Quant.csv
# 8 2 347 138
# 15 ADT2_YEAST.Quant.csv
# 8 2 354 139
# 16 ADY2_YEAST.Quant.csv
# 8 2 354 139
# 17 AHP1_YEAST.Quant.csv
# 8 2 363 145
# 18 AIM2_YEAST.Quant.csv
# 8 2 363 145
# 19 ALDH4_YEAST.Quant.csv
# 8 2 411 152
# 20 ALDH6_YEAST.Quant.csv
# 8 2 522 170
# 21 ALF_YEAST.Quant.csv
# 8 2 573 195
# 22 AMPL_YEAST.Quant.csv
# 8 2 590 197
# 23 APE2_YEAST.Quant.csv
# 8 2 591 197
# 24 ARA1_YEAST.Quant.csv
# 8 2 599 198
# 25 ARC1_YEAST.Quant.csv
# 8 2 608 201
# 26 ARF1_YEAST.Quant.csv
# 8 2 620 204
# 27 ARF2_YEAST.Quant.csv
# 8 2 621 204
# 28 ARGI_YEAST.Quant.csv
# 8 2 621 204
# 29 ARO8_YEAST.Quant.csv
# 8 2 665 211
# 30 ARO9_YEAST.Quant.csv
# 8 2 668 215
# 31 AROC_YEAST.Quant.csv
# 8 2 668 215
# 32 AROF_YEAST.Quant.csv
# 8 2 668 215
# 33 AROG_YEAST.Quant.csv
# 8 2 669 215
# 34 ARP2_YEAST.Quant.csv
# 8 2 669 218
# 35 ASNS1_YEAST.Quant.csv
# 8 2 670 219
# 36 ASNS2_YEAST.Quant.csv
# 8 2 672 219
# 37 ATIF_YEAST.Quant.csv
# 8 2 672 219
# 38 ATO2_YEAST.Quant.csv
# 8 2 672 219
# 39 ATP7_YEAST.Quant.csv
# 8 2 672 219
# 40 ATPA_YEAST.Quant.csv
# 8 2 712 225
# 41 ATPB_YEAST.Quant.csv
# 8 2 722 229
# 42 ATPD_YEAST.Quant.csv
# 8 2 722 229
# 43 ATPF_YEAST.Quant.csv
# 8 2 743 234
# 44 ATPG_YEAST.Quant.csv
# 8 2 743 234
# 45 ATPO_YEAST.Quant.csv
# 8 2 773 240
# 46 BCA1_YEAST.Quant.csv
# 8 2 777 240
# 47 BCA2_YEAST.Quant.csv
# 8 2 781 240
# 48 BFR1_YEAST.Quant.csv
# 8 2 793 243
# 49 BGL2_YEAST.Quant.csv
# 8 2 793 243
# 50 BIP_YEAST.Quant.csv
# 8 2 815 250
# 51 BMH1_YEAST.Quant.csv
# 12 3 831 251
# 52 BMH2_YEAST.Quant.csv
# 12 3 831 251
# 53 C1TC_YEAST.Quant.csv
# 12 3 833 257
# 54 CACM_YEAST.Quant.csv
# 12 3 833 257
# 55 CACP_YEAST.Quant.csv
# 12 3 850 261
# 56 CALM_YEAST.Quant.csv
# 12 3 850 261
# 57 CAP_YEAST.Quant.csv
# 12 3 869 267
# 58 CARP_YEAST.Quant.csv
# 12 3 884 273
# 59 CBPS_YEAST.Quant.csv
# 12 3 884 273
# 60 CBPY_YEAST.Quant.csv
# 12 3 884 273
# 61 CBS_YEAST.Quant.csv
# 12 3 907 277
# 62 CCPR_YEAST.Quant.csv
# 12 3 920 277
# 63 CDC48_YEAST.Quant.csv
# 18 3 935 277
# 64 CH10_YEAST.Quant.csv
# 18 3 948 279
# 65 CISY1_YEAST.Quant.csv
# 18 3 975 291
# 66 CLC1_YEAST.Quant.csv
# 18 3 975 291
# 67 CLH_YEAST.Quant.csv
# 18 3 987 293
# 68 CLU_YEAST.Quant.csv
# 18 3 997 305
# 69 COFI_YEAST.Quant.csv
# 18 3 1004 305
# 70 COX12_YEAST.Quant.csv
# 18 3 1004 305
# 71 COX2_YEAST.Quant.csv
# 18 3 1004 305
# 72 COX4_YEAST.Quant.csv
# 18 3 1004 305
# 73 CYC1_YEAST.Quant.csv
# 18 3 1004 305
# 74 CYPC_YEAST.Quant.csv
# 18 3 1004 305
# 75 CYPD_YEAST.Quant.csv
# 18 3 1018 305
# 76 CYPH_YEAST.Quant.csv
# 18 3 1037 306
# 77 CYS3_YEAST.Quant.csv
# 18 3 1050 309
# 78 DAK1_YEAST.Quant.csv
# 18 3 1055 310
# 79 DCPS_YEAST.Quant.csv
# 18 3 1061 311
# 80 DHAS_YEAST.Quant.csv
# 18 3 1061 311
# 81 DHE4_YEAST.Quant.csv
# 18 3 1098 323
# 82 DHE5_YEAST.Quant.csv
# 18 3 1099 323
# 83 DHOM_YEAST.Quant.csv
# 18 3 1111 329
# 84 DLD1_YEAST.Quant.csv
# 18 3 1111 329
# 85 DLDH_YEAST.Quant.csv
# 18 3 1149 334
# 86 DPM1_YEAST.Quant.csv
# 18 3 1153 337
# 87 DUG1_YEAST.Quant.csv
# 18 3 1167 340
# 88 EF1A_YEAST.Quant.csv
# 18 3 1226 349
# 89 EF1B_YEAST.Quant.csv
# 18 3 1231 350
# 90 EF1G1_YEAST.Quant.csv
# 18 3 1248 353
# 91 EF1G2_YEAST.Quant.csv
# 18 3 1264 359
# 92 EF2_YEAST.Quant.csv
# 161 35 1394 406
# 93 EF3A_YEAST.Quant.csv
# 161 35 1552 431
# 94 EFTU_YEAST.Quant.csv
# 161 35 1575 431
# 95 EIF3J_YEAST.Quant.csv
# 161 35 1575 431
# 96 ENO1_YEAST.Quant.csv
# 161 35 1623 446
# 97 ENO2_YEAST.Quant.csv
# 161 35 1664 469
# 98 ERF1_YEAST.Quant.csv
# 161 35 1665 469
# 99 ERF3_YEAST.Quant.csv
# 161 35 1665 469
# 100 ERG6_YEAST.Quant.csv
# 161 35 1665 469
# 101 ERR1_YEAST.Quant.csv
# 161 35 1669 474
# 102 F16P_YEAST.Quant.csv
# 161 35 1709 480
# 103 FAS1_YEAST.Quant.csv
# 161 35 1772 510
# 104 FAS2_YEAST.Quant.csv
# 161 35 1815 527
# 105 FAT2_YEAST.Quant.csv
# 161 35 1817 528
# 106 FHP_YEAST.Quant.csv
# 161 35 1829 528
# 107 FIMB_YEAST.Quant.csv
# 161 35 1849 530
# 108 FKBP3_YEAST.Quant.csv
# 161 35 1849 530
# 109 FKBP_YEAST.Quant.csv
# 161 35 1858 531
# 110 FPPS_YEAST.Quant.csv
# 161 35 1865 537
# 111 FRDS_YEAST.Quant.csv
# 161 35 1865 537
# 112 FUMH_YEAST.Quant.csv
# 161 35 1874 539
# 113 G3P1_YEAST.Quant.csv
# 161 35 1922 543
# 114 G3P2_YEAST.Quant.csv
# 161 35 1947 553
# 115 G3P3_YEAST.Quant.csv
# 161 35 1986 558
# 116 G6PI_YEAST.Quant.csv
# 161 35 2041 579
# 117 GAS1_YEAST.Quant.csv
# 161 35 2041 579
# 118 GBLP_YEAST.Quant.csv
# 161 35 2043 579
# 119 GDI1_YEAST.Quant.csv
# 161 35 2043 579
# 120 GLNA_YEAST.Quant.csv
# 161 35 2064 582
# 121 GLRX1_YEAST.Quant.csv
# 161 35 2064 582
# 122 GLRX2_YEAST.Quant.csv
# 161 35 2064 582
# 123 GLT1_YEAST.Quant.csv
# 161 35 2064 582
# 124 GLYC_YEAST.Quant.csv
# 161 35 2079 586
# 125 GLYM_YEAST.Quant.csv
# 161 35 2080 586
# 126 GPD1_YEAST.Quant.csv
# 161 35 2109 587
# 127 GPDM_YEAST.Quant.csv
# 161 35 2111 592
# 128 GPX3_YEAST.Quant.csv
# 161 35 2111 592
# 129 GRE1_YEAST.Quant.csv
# 161 35 2114 595
# 130 GSHR_YEAST.Quant.csv
# 161 35 2121 595
# 131 GUAA_YEAST.Quant.csv
# 161 35 2124 606
# 132 GVP36_YEAST.Quant.csv
# 161 35 2146 608
# 133 H2A1_YEAST.Quant.csv
# 161 35 2146 608
# 134 H2B1_YEAST.Quant.csv
# 161 35 2160 608
# 135 H4_YEAST.Quant.csv
# 161 35 2161 611
# 136 HBT1_YEAST.Quant.csv
# 161 35 2164 612
# 137 HIS2_YEAST.Quant.csv
# 161 35 2164 612
# 138 HMCS_YEAST.Quant.csv
# 161 35 2164 612
# 139 HMO1_YEAST.Quant.csv
# 161 35 2165 613
# 140 HNT1_YEAST.Quant.csv
# 161 35 2167 613
# 141 HS104_YEAST.Quant.csv
# 161 35 2213 623
# 142 HSC82_YEAST.Quant.csv
# 161 35 2273 644
# 143 HSP12_YEAST.Quant.csv
# 161 35 2276 646
# 144 HSP26_YEAST.Quant.csv
# 161 35 2283 646
# 145 HSP30_YEAST.Quant.csv
# 161 35 2285 647
# 146 HSP60_YEAST.Quant.csv
# 161 35 2364 662
# 147 HSP71_YEAST.Quant.csv
# 161 35 2446 715
# 148 HSP72_YEAST.Quant.csv
# 161 35 2459 718
# 149 HSP73_YEAST.Quant.csv
# 161 35 2459 718
# 150 HSP74_YEAST.Quant.csv
# 161 35 2464 727
# 151 HSP77_YEAST.Quant.csv
# 161 35 2493 747
# 152 HSP78_YEAST.Quant.csv
# 161 35 2498 748
# 153 HSP79_YEAST.Quant.csv
# 161 35 2498 748
# 154 HSP7F_YEAST.Quant.csv
# 161 35 2527 750
# 155 HSP82_YEAST.Quant.csv
# 161 35 2537 752
# 156 HXKA_YEAST.Quant.csv
# 161 35 2606 764
# 157 HXKB_YEAST.Quant.csv
# 161 35 2641 776
# 158 HXKG_YEAST.Quant.csv
# 161 35 2672 790
# 159 HXT6_YEAST.Quant.csv
# 161 35 2701 792
# 160 IDH1_YEAST.Quant.csv
# 161 35 2724 801
# 161 IDH2_YEAST.Quant.csv
# 161 35 2765 802
# 162 IDHC_YEAST.Quant.csv
# 161 35 2780 832
# 163 IDHP_YEAST.Quant.csv
# 161 35 2788 833
# 164 IF2B_YEAST.Quant.csv
# 161 35 2788 833
# 165 IF4B_YEAST.Quant.csv
# 161 35 2788 833
# 166 IF4E_YEAST.Quant.csv
# 161 35 2789 833
# 167 IF5A1_YEAST.Quant.csv
# 161 35 2811 839
# 168 ILV3_YEAST.Quant.csv
# 161 35 2857 856
# 169 ILV5_YEAST.Quant.csv
# 161 35 2914 872
# 170 ILV6_YEAST.Quant.csv
# 161 35 2914 872
# 171 ILVB_YEAST.Quant.csv
# 161 35 2914 872
# 172 IMB4_YEAST.Quant.csv
# 161 35 2927 880
# 173 IMDH3_YEAST.Quant.csv
# 161 35 2962 887
# 174 IMDH4_YEAST.Quant.csv
# 161 35 2962 887
# 175 INO1_YEAST.Quant.csv
# 161 35 2980 894
# 176 IPYR_YEAST.Quant.csv
# 161 35 3019 909
# 177 KAR_YEAST.Quant.csv
# 161 35 3019 909
# 178 KPYK1_YEAST.Quant.csv
# 161 35 3060 929
# 179 LCF1_YEAST.Quant.csv
# 161 35 3068 929
# 180 LEU1_YEAST.Quant.csv
# 161 35 3071 929
# 181 LSP1_YEAST.Quant.csv
# 161 35 3075 929
# 182 MAS5_YEAST.Quant.csv
# 161 35 3075 929
# 183 MBF1_YEAST.Quant.csv
# 161 35 3076 929
# 184 MDHC_YEAST.Quant.csv
# 161 35 3127 940
# 185 MDHM_YEAST.Quant.csv
# 161 35 3165 948
# 186 METE_YEAST.Quant.csv
# 161 35 3186 963
# 187 METK1_YEAST.Quant.csv
# 161 35 3190 974
# 188 MLC1_YEAST.Quant.csv
# 161 35 3196 985
# 189 MLS1_YEAST.Quant.csv
# 161 35 3260 991
# 190 MMF1_YEAST.Quant.csv
# 161 35 3266 992
# 191 MPCP_YEAST.Quant.csv
# 161 35 3288 997
# 192 MPG1_YEAST.Quant.csv
# 161 35 3307 1003
# 193 MPI_YEAST.Quant.csv
# 161 35 3307 1003
# 194 MSC1_YEAST.Quant.csv
# 161 35 3307 1003
# 195 NACA_YEAST.Quant.csv
# 161 35 3324 1009
# 196 NAP1_YEAST.Quant.csv
# 161 35 3324 1009
# 197 NDK_YEAST.Quant.csv
# 161 35 3330 1011
# 198 NHP6A_YEAST.Quant.csv
# 161 35 3330 1011
# 199 NOP3_YEAST.Quant.csv
# 161 35 3334 1014
# 200 NPT1_YEAST.Quant.csv
# 161 35 3335 1016
# 201 ODO1_YEAST.Quant.csv
# 161 35 3393 1035
# 202 ODO2_YEAST.Quant.csv
# 161 35 3423 1062
# 203 ODP2_YEAST.Quant.csv
# 161 35 3423 1062
# 204 ODPA_YEAST.Quant.csv
# 161 35 3462 1066
# 205 ODPB_YEAST.Quant.csv
# 161 35 3489 1071
# 206 OLA1_YEAST.Quant.csv
# 161 35 3506 1073
# 207 OM45_YEAST.Quant.csv
# 161 35 3516 1073
# 208 OYE2_YEAST.Quant.csv
# 161 35 3547 1085
# 209 P5CR_YEAST.Quant.csv
# 161 35 3547 1085
# 210 PAA1_YEAST.Quant.csv
# 161 35 3547 1085
# 211 PABP_YEAST.Quant.csv
# 161 35 3556 1089
# 212 PCKA_YEAST.Quant.csv
# 161 35 3637 1123
# 213 PDC1_YEAST.Quant.csv
# 161 35 3703 1136
# 214 PDI_YEAST.Quant.csv
# 161 35 3707 1137
# 215 PET10_YEAST.Quant.csv
# 161 35 3725 1140
# 216 PFKA1_YEAST.Quant.csv
# 161 35 3864 1178
# 217 PFKA2_YEAST.Quant.csv
# 161 35 3917 1188
# 218 PGK_YEAST.Quant.csv
# 161 35 3987 1190
# 219 PGM2_YEAST.Quant.csv
# 161 35 4028 1193
# 220 PHSG_YEAST.Quant.csv
# 161 35 4042 1211
# 221 PIL1_YEAST.Quant.csv
# 161 35 4053 1214
# 222 PMA1_YEAST.Quant.csv
# 161 35 4105 1222
# 223 PMG1_YEAST.Quant.csv
# 161 35 4137 1237
# 224 PMM_YEAST.Quant.csv
# 161 35 4145 1240
# 225 PNC1_YEAST.Quant.csv
# 161 35 4154 1241
# 226 PP12_YEAST.Quant.csv
# 161 35 4155 1243
# 227 PP2A1_YEAST.Quant.csv
# 161 35 4157 1243
# 228 PPID_YEAST.Quant.csv
# 161 35 4159 1243
# 229 PRS8_YEAST.Quant.csv
# 161 35 4159 1243
# 230 PRTB_YEAST.Quant.csv
# 161 35 4170 1243
# 231 PRX1_YEAST.Quant.csv
# 161 35 4197 1251
# 232 PSA1_YEAST.Quant.csv
# 161 35 4197 1251
# 233 PST2_YEAST.Quant.csv
# 161 35 4211 1255
# 234 PUR2_YEAST.Quant.csv
# 161 35 4220 1255
# 235 PUR4_YEAST.Quant.csv
# 161 35 4232 1263
# 236 PUR7_YEAST.Quant.csv
# 161 35 4252 1270
# 237 PUR8_YEAST.Quant.csv
# 161 35 4290 1276
# 238 PUR92_YEAST.Quant.csv
# 161 35 4319 1280
# 239 PURA_YEAST.Quant.csv
# 161 35 4333 1292
# 240 PYC1_YEAST.Quant.csv
# 161 35 4373 1311
# 241 PYP1_YEAST.Quant.csv
# 161 35 4389 1313
# 242 PYR1_YEAST.Quant.csv
# 161 35 4562 1370
# 243 PYRD_YEAST.Quant.csv
# 161 35 4566 1370
# 244 QCR1_YEAST.Quant.csv
# 161 35 4605 1373
# 245 QCR2_YEAST.Quant.csv
# 161 35 4663 1385
# 246 QCR7_YEAST.Quant.csv
# 161 35 4676 1385
# 247 RDL1_YEAST.Quant.csv
# 161 35 4676 1385
# 248 RHO1_YEAST.Quant.csv
# 161 35 4676 1385
# 249 RIB4_YEAST.Quant.csv
# 161 35 4677 1386
# 250 RIM1_YEAST.Quant.csv
# 161 35 4677 1387
# 251 RIR2_YEAST.Quant.csv
# 161 35 4706 1391
# 252 RIR4_YEAST.Quant.csv
# 161 35 4718 1393
# 253 RL10_YEAST.Quant.csv
# 161 35 4736 1393
# 254 RL11A_YEAST.Quant.csv
# 161 35 4736 1393
# 255 RL11B_YEAST.Quant.csv
# 161 35 4736 1393
# 256 RL12A_YEAST.Quant.csv
# 161 35 4759 1393
# 257 RL13A_YEAST.Quant.csv
# 161 35 4759 1393
# 258 RL14A_YEAST.Quant.csv
# 161 35 4759 1393
# 259 RL15A_YEAST.Quant.csv
# 161 35 4776 1399
# 260 RL16A_YEAST.Quant.csv
# 161 35 4776 1399
# 261 RL16B_YEAST.Quant.csv
# 161 35 4782 1401
# 262 RL17A_YEAST.Quant.csv
# 161 35 4796 1401
# 263 RL18A_YEAST.Quant.csv
# 161 35 4798 1403
# 264 RL19A_YEAST.Quant.csv
# 161 35 4798 1403
# 265 RL1A_YEAST.Quant.csv
# 161 35 4798 1405
# 266 RL20A_YEAST.Quant.csv
# 161 35 4799 1405
# 267 RL22A_YEAST.Quant.csv
# 161 35 4817 1405
# 268 RL23A_YEAST.Quant.csv
# 161 35 4820 1405
# 269 RL25_YEAST.Quant.csv
# 161 35 4825 1405
# 270 RL26A_YEAST.Quant.csv
# 161 35 4825 1405
# 271 RL27A_YEAST.Quant.csv
# 161 35 4828 1411
# 272 RL28_YEAST.Quant.csv
# 161 35 4829 1411
# 273 RL2A_YEAST.Quant.csv
# 161 35 4829 1411
# 274 RL30_YEAST.Quant.csv
# 161 35 4851 1418
# 275 RL31A_YEAST.Quant.csv
# 161 35 4851 1418
# 276 RL33A_YEAST.Quant.csv
# 161 35 4853 1418
# 277 RL35A_YEAST.Quant.csv
# 161 35 4868 1418
# 278 RL36A_YEAST.Quant.csv
# 161 35 4893 1418
# 279 RL3_YEAST.Quant.csv
# 161 35 4913 1425
# 280 RL43A_YEAST.Quant.csv
# 161 35 4913 1425
# 281 RL4A_YEAST.Quant.csv
# 161 35 4942 1431
# 282 RL5_YEAST.Quant.csv
# 161 35 4944 1433
# 283 RL6A_YEAST.Quant.csv
# 161 35 4947 1440
# 284 RL6B_YEAST.Quant.csv
# 161 35 4947 1440
# 285 RL7A_YEAST.Quant.csv
# 161 35 4972 1440
# 286 RL8A_YEAST.Quant.csv
# 161 35 4978 1443
# 287 RL8B_YEAST.Quant.csv
# 161 35 4979 1444
# 288 RL9A_YEAST.Quant.csv
# 161 35 4980 1447
# 289 RLA0_YEAST.Quant.csv
# 161 35 4981 1448
# 290 RLA2_YEAST.Quant.csv
# 161 35 4994 1449
# 291 RLA3_YEAST.Quant.csv
# 161 35 4994 1449
# 292 RLA4_YEAST.Quant.csv
# 161 35 4994 1449
# 293 RS10A_YEAST.Quant.csv
# 161 35 5005 1450
# 294 RS11A_YEAST.Quant.csv
# 161 35 5015 1456
# 295 RS12_YEAST.Quant.csv
# 161 35 5015 1456
# 296 RS13_YEAST.Quant.csv
# 161 35 5040 1456
# 297 RS15_YEAST.Quant.csv
# 161 35 5060 1457
# 298 RS16A_YEAST.Quant.csv
# 161 35 5061 1458
# 299 RS18A_YEAST.Quant.csv
# 161 35 5063 1459
# 300 RS19A_YEAST.Quant.csv
# 161 35 5072 1459
# 301 RS20_YEAST.Quant.csv
# 161 35 5077 1460
# 302 RS21A_YEAST.Quant.csv
# 161 35 5078 1460
# 303 RS22A_YEAST.Quant.csv
# 161 35 5111 1470
# 304 RS23A_YEAST.Quant.csv
# 161 35 5113 1471
# 305 RS24A_YEAST.Quant.csv
# 161 35 5113 1471
# 306 RS26A_YEAST.Quant.csv
# 162 35 5113 1471
# 307 RS27A_YEAST.Quant.csv
# 162 35 5113 1471
# 308 RS28A_YEAST.Quant.csv
# 162 35 5117 1471
# 309 RS2_YEAST.Quant.csv
# 162 35 5120 1475
# 310 RS31_YEAST.Quant.csv
# 162 35 5120 1476
# 311 RS3_YEAST.Quant.csv
# 162 35 5126 1476
# 312 RS4A_YEAST.Quant.csv
# 162 35 5129 1479
# 313 RS5_YEAST.Quant.csv
# 162 35 5154 1484
# 314 RS6A_YEAST.Quant.csv
# 162 35 5164 1484
# 315 RS7A_YEAST.Quant.csv
# 162 35 5164 1485
# 316 RS8A_YEAST.Quant.csv
# 162 35 5176 1489
# 317 RS9B_YEAST.Quant.csv
# 162 35 5176 1489
# 318 SAC1_YEAST.Quant.csv
# 162 35 5176 1489
# 319 SAHH_YEAST.Quant.csv
# 162 35 5188 1493
# 320 SAM4_YEAST.Quant.csv
# 162 35 5188 1493
# 321 SC160_YEAST.Quant.csv
# 162 35 5195 1500
# 322 SDHA_YEAST.Quant.csv
# 162 35 5206 1510
# 323 SDHB_YEAST.Quant.csv
# 162 35 5229 1519
# 324 SEC14_YEAST.Quant.csv
# 162 35 5229 1523
# 325 SERC_YEAST.Quant.csv
# 162 35 5229 1523
# 326 SFC1_YEAST.Quant.csv
# 162 35 5234 1526
# 327 SGT2_YEAST.Quant.csv
# 162 35 5239 1526
# 328 SIS1_YEAST.Quant.csv
# 162 35 5281 1529
# 329 SMT3_YEAST.Quant.csv
# 162 35 5282 1529
# 330 SODC_YEAST.Quant.csv
# 162 35 5289 1529
# 331 SODM_YEAST.Quant.csv
# 162 35 5307 1531
# 332 SSB1_YEAST.Quant.csv
# 162 35 5387 1546
# 333 SSB2_YEAST.Quant.csv
# 162 35 5396 1549
# 334 SSBP1_YEAST.Quant.csv
# 162 35 5405 1551
# 335 SSZ1_YEAST.Quant.csv
# 162 35 5468 1563
# 336 STI1_YEAST.Quant.csv
# 162 35 5486 1574
# 337 STM1_YEAST.Quant.csv
# 162 35 5486 1574
# 338 SUCA_YEAST.Quant.csv
# 162 35 5495 1576
# 339 SUCB_YEAST.Quant.csv
# 162 35 5496 1576
# 340 SUI1_YEAST.Quant.csv
# 162 35 5497 1576
# 341 SYA_YEAST.Quant.csv
# 162 35 5527 1590
# 342 SYDC_YEAST.Quant.csv
# 162 35 5549 1595
# 343 SYEC_YEAST.Quant.csv
# 162 35 5574 1614
# 344 SYFB_YEAST.Quant.csv
# 162 35 5581 1622
# 345 SYG_YEAST.Quant.csv
# 162 35 5611 1637
# 346 SYH_YEAST.Quant.csv
# 162 35 5611 1638
# 347 SYIC_YEAST.Quant.csv
# 162 35 5689 1666
# 348 SYKC_YEAST.Quant.csv
# 162 35 5720 1678
# 349 SYLC_YEAST.Quant.csv
# 162 35 5753 1679
# 350 SYNC_YEAST.Quant.csv
# 162 35 5758 1679
# 351 SYRC_YEAST.Quant.csv
# 162 35 5796 1688
# 352 SYSC_YEAST.Quant.csv
# 162 35 5831 1704
# 353 SYTC_YEAST.Quant.csv
# 162 35 5843 1710
# 354 SYV_YEAST.Quant.csv
# 162 35 5854 1722
# 355 SYYC_YEAST.Quant.csv
# 162 35 5854 1722
# 356 TAL1_YEAST.Quant.csv
# 162 35 5872 1735
# 357 TBA1_YEAST.Quant.csv
# 162 35 5883 1752
# 358 TBB_YEAST.Quant.csv
# 162 35 5883 1752
# 359 TCTP_YEAST.Quant.csv
# 162 35 5899 1752
# 360 THIL_YEAST.Quant.csv
# 162 35 5902 1755
# 361 THRC_YEAST.Quant.csv
# 162 35 5908 1761
# 362 TIM9_YEAST.Quant.csv
# 162 35 5908 1761
# 363 TKT1_YEAST.Quant.csv
# 162 35 5936 1771
# 364 TPIS_YEAST.Quant.csv
# 162 35 5983 1778
# 365 TPM1_YEAST.Quant.csv
# 162 35 5998 1778
# 366 TPS1_YEAST.Quant.csv
# 162 35 6026 1779
# 367 TRP_YEAST.Quant.csv
# 162 35 6093 1781
# 368 TRX1_YEAST.Quant.csv
# 162 35 6095 1785
# 369 TRX2_YEAST.Quant.csv
# 162 35 6101 1794
# 370 TRXB1_YEAST.Quant.csv
# 162 35 6113 1795
# 371 TSA1_YEAST.Quant.csv
# 162 35 6140 1809
# 372 TSL1_YEAST.Quant.csv
# 162 35 6178 1835
# 373 UBA1_YEAST.Quant.csv
# 162 35 6178 1835
# 374 UCRI_YEAST.Quant.csv
# 162 35 6184 1850
# 375 UGPA1_YEAST.Quant.csv
# 162 35 6212 1859
# 376 VATA_YEAST.Quant.csv
# 162 35 6266 1868
# 377 VATB_YEAST.Quant.csv
# 162 35 6352 1895
# 378 VATE_YEAST.Quant.csv
# 162 35 6371 1897
# 379 VATH_YEAST.Quant.csv
# 162 35 6371 1897
# 380 VDAC1_YEAST.Quant.csv
# 162 35 6382 1898
# 381 VPS1_YEAST.Quant.csv
# 162 35 6391 1905
# 382 VPS21_YEAST.Quant.csv
# 162 35 6391 1905
# 383 WTM1_YEAST.Quant.csv
# 162 35 6413 1914
# 384 YCP4_YEAST.Quant.csv
# 162 35 6420 1915
# 385 YGP1_YEAST.Quant.csv
# 162 35 6420 1915
# 386 YHI0_YEAST.Quant.csv
# 162 35 6426 1916
# 387 YL179_YEAST.Quant.csv
# 162 35 6426 1916
# 388 YN034_YEAST.Quant.csv
# 162 35 6426 1916
# 389 YNN4_YEAST.Quant.csv
# 162 35 6454 1918
# 390 YNU8_YEAST.Quant.csv
# 162 35 6467 1922
# 391 YP010_YEAST.Quant.csv
# 162 35 6467 1922
# 392 YP225_YEAST.Quant.csv
# 162 35 6482 1922
# 393 YPT1_YEAST.Quant.csv
# 162 35 6482 1922
# 394 YPT31_YEAST.Quant.csv
# 162 35 6482 1922
# 395 YRB1_YEAST.Quant.csv
# 162 35 6482 1922
# 396 ZEO1_YEAST.Quant.csv
# 162 35 6484 1923
# 397 ZPR1_YEAST.Quant.csv
# 162 35 6487 1931
# 398 ZUO1_YEAST.Quant.csv
# 162 35 6501 1936

# %%
sum(ndk.values())
# Out:
# 13

# %%
ndk
# Out:
# {9: 2, 16: 5, 5: 1, 11: 1, 12: 1, 15: 1, 17: 1, 18: 1}

# %%
TN=0
FN=0
FP=0
TP=0
start=12

ZEROIONSCORE_WITHVALUE=dict()
dictpept={}
ndk=dict()




nonzeropoints=0
elu_window=0

# temp_fillalldata=pd.read_csv( filepath+files[0],skiprows=3,index_col=False)  
temp_fillalldata=pd.read_csv(filepath+files[0],header=None,skiprows=2,index_col=False)  
temp_fillalldata.fillna(-500)

for row in range(temp_fillalldata.shape[0]):

    #read experiments
    expriments=[]
    for i in range(40):
        try:
            expriments.append(list(temp_fillalldata.iloc[row,start +i*16:(start+16)+ i*16].astype('float')))
        except:
            expriments.append([-500]*16)
        if(i>19 and (expriments[-1][1])>0): # check ionscore
            nonzeropoints+=1 # count nonzero ionscore points
            if(sum(expriments[-1][5:11])>0): # to compute elution window
                elu_window=abs(expriments[-1][11]-expriments[-1][12])

    if nonzeropoints >=4:
        for i in range(20):
            dictpept[i]=dictpept.get(i,0)+1
            temp=expriments[i]
            if(temp[1]==0):#ionscore ==0 temp[1]==100 or 
                isotopsum=sum(temp[5:11])
                if( isotopsum ==0 or isotopsum < 1E5 or abs(temp[11]-temp[12])<= 0.5*elu_window):
                    TN+=1
                elif(isotopsum>0):
                    FP+=1
                    dictcount[i]=dictcount.get(i,0)+1
            elif(temp[1]>=0 and temp[1] != 100):
                ndk[i]=ndk.get(i,0)+1

# %%
dictcount
# ndk
# Out:
# {0: 3,
#  1: 3,
#  2: 3,
#  3: 3,
#  4: 3,
#  5: 3,
#  6: 3,
#  7: 3,
#  8: 3,
#  9: 3,
#  10: 3,
#  11: 3,
#  12: 3,
#  13: 3,
#  14: 3,
#  15: 3,
#  16: 3,
#  17: 3,
#  18: 3,
#  19: 3}

# %%
# dictpept

# %%
FP
# Out:
# 0

# %%
TN=0
FN=0
FP=0
TP=0
start=12

ZEROIONSCORE_WITHVALUE=dict()
dictpept={}
ndk=dict()
proteincount=0

for f in range(len(files)):#len(files)

    try:
        print(f,files[f])

        nonzeropoints=0
        elu_window=0

#         temp_fillalldata=pd.read_csv( filepath+files[f],skiprows=3,index_col=False)  
        temp_fillalldata=pd.read_csv(filepath+files[f],header=None,skiprows=2,index_col=False)  
        temp_fillalldata.fillna(-500)
        
#         if temp_fillalldata.shape[0]<4: continue
#         else: 
        proteincount=proteincount+1

        for row in range(temp_fillalldata.shape[0]):

            #read experiments
            expriments=[]
            for i in range(40):
                try:
                    expriments.append(list(temp_fillalldata.iloc[row,start +i*16:(start+16)+ i*16].astype('float')))
                except:
                    expriments.append([-500]*16)
                if(i>19 and (expriments[-1][1])>0): # check ionscore
                    nonzeropoints+=1 # count nonzero ionscore points
                    if(sum(expriments[-1][5:11])>0): # to compute elution window
                        elu_window=abs(expriments[-1][11]-expriments[-1][12])

            if nonzeropoints >=4:
                for i in range(20):
                    dictpept[i]=dictpept.get(i,0)+1
                    temp=expriments[i]
                    if(temp[1]==0):#ionscore ==0 temp[1]==100 or 
                        isotopsum=sum(temp[5:11])
                        if( isotopsum ==0 or isotopsum < 1E5 or abs(temp[11]-temp[12])<= 0.5*elu_window):
                            TN+=1
                        elif(isotopsum>0):
                            FP+=1
                            ZEROIONSCORE_WITHVALUE[i]=ZEROIONSCORE_WITHVALUE.get(i,0)+1
                    elif(temp[1]>=0 and temp[1] != 100):
                        ndk[i]=ndk.get(i,0)+1
                        

#                 for i in range(20,40):
#                     temp=expriments[i]
#                     if(temp[1]==0): #ionscore ==0
#                         isotopsum=sum(temp[5:11])
#                         if( isotopsum > 0 and isotopsum > 1E5 and abs(temp[11]-temp[12])>= 0.5*elu_window):
#                             TP+=1
#                         elif(isotopsum==0 or isotopsum < 1E5 or abs(temp[11]-temp[12])<= 0.5*elu_window):
#                             FN+=1

        print(TN,FP,TP,FN)
    except:
        print("E",files[f])
# Out:
# 0 6PGD1_YEAST.Quant.csv
# 12 0 0 0
# 1 AATC_YEAST.Quant.csv
# 12 0 0 0
# 2 ABF2_YEAST.Quant.csv
# E ABF2_YEAST.Quant.csv
# 3 ABP1_YEAST.Quant.csv
# 12 0 0 0
# 4 ACAC_YEAST.Quant.csv
# 12 0 0 0
# 5 ACBP_YEAST.Quant.csv
# 12 0 0 0
# 6 ACEA_YEAST.Quant.csv
# 12 0 0 0
# 7 ACH1_YEAST.Quant.csv
# 12 0 0 0
# 8 ACON_YEAST.Quant.csv
# 12 0 0 0
# 9 ACS1_YEAST.Quant.csv
# 12 0 0 0
# 10 ACT_YEAST.Quant.csv
# 12 0 0 0
# 11 ADH1_YEAST.Quant.csv
# 12 0 0 0
# 12 ADH2_YEAST.Quant.csv
# 12 0 0 0
# 13 ADH3_YEAST.Quant.csv
# 12 0 0 0
# 14 ADH6_YEAST.Quant.csv
# 12 0 0 0
# 15 ADK_YEAST.Quant.csv
# 12 0 0 0
# 16 ADT2_YEAST.Quant.csv
# 12 0 0 0
# 17 ADY2_YEAST.Quant.csv
# 12 0 0 0
# 18 AHP1_YEAST.Quant.csv
# 12 0 0 0
# 19 AIM2_YEAST.Quant.csv
# 12 0 0 0
# 20 ALDH4_YEAST.Quant.csv
# 12 0 0 0
# 21 ALDH6_YEAST.Quant.csv
# 12 0 0 0
# 22 ALF_YEAST.Quant.csv
# 12 0 0 0
# 23 AMPL_YEAST.Quant.csv
# 12 0 0 0
# 24 APE2_YEAST.Quant.csv
# 12 0 0 0
# 25 APE3_YEAST.Quant.csv
# E APE3_YEAST.Quant.csv
# 26 APT1_YEAST.Quant.csv
# 12 0 0 0
# 27 ARA1_YEAST.Quant.csv
# 12 0 0 0
# 28 ARB1_YEAST.Quant.csv
# E ARB1_YEAST.Quant.csv
# 29 ARC1_YEAST.Quant.csv
# 12 0 0 0
# 30 ARF1_YEAST.Quant.csv
# 12 0 0 0
# 31 ARF2_YEAST.Quant.csv
# 12 0 0 0
# 32 ARGI_YEAST.Quant.csv
# 12 0 0 0
# 33 ARO8_YEAST.Quant.csv
# 12 0 0 0
# 34 ARO9_YEAST.Quant.csv
# 12 0 0 0
# 35 AROC_YEAST.Quant.csv
# 12 0 0 0
# 36 AROF_YEAST.Quant.csv
# E AROF_YEAST.Quant.csv
# 37 AROG_YEAST.Quant.csv
# 12 0 0 0
# 38 ARP2_YEAST.Quant.csv
# 12 0 0 0
# 39 ARP3_YEAST.Quant.csv
# E ARP3_YEAST.Quant.csv
# 40 ASNS1_YEAST.Quant.csv
# 12 0 0 0
# 41 ASNS2_YEAST.Quant.csv
# E ASNS2_YEAST.Quant.csv
# 42 ATIF_YEAST.Quant.csv
# E ATIF_YEAST.Quant.csv
# 43 ATO2_YEAST.Quant.csv
# 12 0 0 0
# 44 ATP7_YEAST.Quant.csv
# E ATP7_YEAST.Quant.csv
# 45 ATPA_YEAST.Quant.csv
# 12 0 0 0
# 46 ATPB_YEAST.Quant.csv
# 12 0 0 0
# 47 ATPD_YEAST.Quant.csv
# E ATPD_YEAST.Quant.csv
# 48 ATPF_YEAST.Quant.csv
# 12 0 0 0
# 49 ATPG_YEAST.Quant.csv
# 12 0 0 0
# 50 ATPO_YEAST.Quant.csv
# 12 0 0 0
# 51 BBC1_YEAST.Quant.csv
# 12 0 0 0
# 52 BCA1_YEAST.Quant.csv
# 12 0 0 0
# 53 BCA2_YEAST.Quant.csv
# 12 0 0 0
# 54 BFR1_YEAST.Quant.csv
# 12 0 0 0
# 55 BGL2_YEAST.Quant.csv
# E BGL2_YEAST.Quant.csv
# 56 BIP_YEAST.Quant.csv
# 12 0 0 0
# 57 BMH1_YEAST.Quant.csv
# 16 0 0 0
# 58 BMH2_YEAST.Quant.csv
# E BMH2_YEAST.Quant.csv
# 59 C1TC_YEAST.Quant.csv
# 16 0 0 0
# 60 CACM_YEAST.Quant.csv
# E CACM_YEAST.Quant.csv
# 61 CACP_YEAST.Quant.csv
# 16 0 0 0
# 62 CALM_YEAST.Quant.csv
# 16 0 0 0
# 63 CAP_YEAST.Quant.csv
# 16 0 0 0
# 64 CARP_YEAST.Quant.csv
# 16 0 0 0
# 65 CBPS_YEAST.Quant.csv
# E CBPS_YEAST.Quant.csv
# 66 CBPY_YEAST.Quant.csv
# 16 0 0 0
# 67 CBS_YEAST.Quant.csv
# 16 0 0 0
# 68 CCPR_YEAST.Quant.csv
# 16 0 0 0
# 69 CDC48_YEAST.Quant.csv
# 25 0 0 0
# 70 CH10_YEAST.Quant.csv
# 25 0 0 0
# 71 CISY1_YEAST.Quant.csv
# 25 0 0 0
# 72 CLC1_YEAST.Quant.csv
# E CLC1_YEAST.Quant.csv
# 73 CLH_YEAST.Quant.csv
# 25 0 0 0
# 74 CLU_YEAST.Quant.csv
# 25 0 0 0
# 75 COFI_YEAST.Quant.csv
# 25 0 0 0
# 76 COPA_YEAST.Quant.csv
# E COPA_YEAST.Quant.csv
# 77 COX12_YEAST.Quant.csv
# E COX12_YEAST.Quant.csv
# 78 COX2_YEAST.Quant.csv
# E COX2_YEAST.Quant.csv
# 79 COX4_YEAST.Quant.csv
# 25 0 0 0
# 80 CRC1_YEAST.Quant.csv
# 25 0 0 0
# 81 CY1_YEAST.Quant.csv
# E CY1_YEAST.Quant.csv
# 82 CYC1_YEAST.Quant.csv
# 25 0 0 0
# 83 CYPC_YEAST.Quant.csv
# E CYPC_YEAST.Quant.csv
# 84 CYPD_YEAST.Quant.csv
# 25 0 0 0
# 85 CYPH_YEAST.Quant.csv
# 25 0 0 0
# 86 CYS3_YEAST.Quant.csv
# 25 0 0 0
# 87 DAK1_YEAST.Quant.csv
# 25 0 0 0
# 88 DCPS_YEAST.Quant.csv
# 25 0 0 0
# 89 DHAS_YEAST.Quant.csv
# 25 0 0 0
# 90 DHE2_YEAST.Quant.csv
# 25 0 0 0
# 91 DHE4_YEAST.Quant.csv
# 25 0 0 0
# 92 DHE5_YEAST.Quant.csv
# E DHE5_YEAST.Quant.csv
# 93 DHOM_YEAST.Quant.csv
# 25 0 0 0
# 94 DLD1_YEAST.Quant.csv
# E DLD1_YEAST.Quant.csv
# 95 DLDH_YEAST.Quant.csv
# 25 0 0 0
# 96 DPM1_YEAST.Quant.csv
# 25 0 0 0
# 97 DUG1_YEAST.Quant.csv
# 25 0 0 0
# 98 EF1A_YEAST.Quant.csv
# 25 0 0 0
# 99 EF1B_YEAST.Quant.csv
# 25 0 0 0
# 100 EF1G1_YEAST.Quant.csv
# 25 0 0 0
# 101 EF1G2_YEAST.Quant.csv
# 25 0 0 0
# 102 EF3A_YEAST.Quant.csv
# 25 0 0 0
# 103 EFTU_YEAST.Quant.csv
# 25 0 0 0
# 104 EIF3A_YEAST.Quant.csv
# E EIF3A_YEAST.Quant.csv
# 105 EIF3J_YEAST.Quant.csv
# E EIF3J_YEAST.Quant.csv
# 106 ENO1_YEAST.Quant.csv
# 25 0 0 0
# 107 ENO2_YEAST.Quant.csv
# 25 0 0 0
# 108 ERF1_YEAST.Quant.csv
# E ERF1_YEAST.Quant.csv
# 109 ERF3_YEAST.Quant.csv
# 25 0 0 0
# 110 ERG6_YEAST.Quant.csv
# E ERG6_YEAST.Quant.csv
# 111 ERR1_YEAST.Quant.csv
# 25 0 0 0
# 112 F16P_YEAST.Quant.csv
# 25 0 0 0
# 113 FAS1_YEAST.Quant.csv
# 25 0 0 0
# 114 FAS2_YEAST.Quant.csv
# 25 0 0 0
# 115 FAT2_YEAST.Quant.csv
# 25 0 0 0
# 116 FHP_YEAST.Quant.csv
# 25 0 0 0
# 117 FIMB_YEAST.Quant.csv
# 25 0 0 0
# 118 FKBP3_YEAST.Quant.csv
# E FKBP3_YEAST.Quant.csv
# 119 FKBP_YEAST.Quant.csv
# 25 0 0 0
# 120 FPPS_YEAST.Quant.csv
# 25 0 0 0
# 121 FRDS_YEAST.Quant.csv
# 25 0 0 0
# 122 FUMH_YEAST.Quant.csv
# 25 0 0 0
# 123 G3P1_YEAST.Quant.csv
# 25 0 0 0
# 124 G3P2_YEAST.Quant.csv
# 25 0 0 0
# 125 G3P3_YEAST.Quant.csv
# 25 0 0 0
# 126 G6PI_YEAST.Quant.csv
# 25 0 0 0
# 127 GAS1_YEAST.Quant.csv
# 25 0 0 0
# 128 GBLP_YEAST.Quant.csv
# 25 0 0 0
# 129 GDI1_YEAST.Quant.csv
# 25 0 0 0
# 130 GLGB_YEAST.Quant.csv
# E GLGB_YEAST.Quant.csv
# 131 GLNA_YEAST.Quant.csv
# 25 0 0 0
# 132 GLRX1_YEAST.Quant.csv
# 25 0 0 0
# 133 GLRX2_YEAST.Quant.csv
# 25 0 0 0
# 134 GLRX3_YEAST.Quant.csv
# E GLRX3_YEAST.Quant.csv
# 135 GLT1_YEAST.Quant.csv
# 25 0 0 0
# 136 GLYC_YEAST.Quant.csv
# 25 0 0 0
# 137 GLYM_YEAST.Quant.csv
# 25 0 0 0
# 138 GPD1_YEAST.Quant.csv
# 25 0 0 0
# 139 GPDM_YEAST.Quant.csv
# 25 0 0 0
# 140 GPP1_YEAST.Quant.csv
# E GPP1_YEAST.Quant.csv
# 141 GPX3_YEAST.Quant.csv
# E GPX3_YEAST.Quant.csv
# 142 GRE1_YEAST.Quant.csv
# 25 0 0 0
# 143 GSHR_YEAST.Quant.csv
# 25 0 0 0
# 144 GUAA_YEAST.Quant.csv
# 25 0 0 0
# 145 GVP36_YEAST.Quant.csv
# 25 0 0 0
# 146 H2A1_YEAST.Quant.csv
# E H2A1_YEAST.Quant.csv
# 147 H2B1_YEAST.Quant.csv
# 25 0 0 0
# 148 H4_YEAST.Quant.csv
# 25 0 0 0
# 149 HBT1_YEAST.Quant.csv
# 25 0 0 0
# 150 HFD1_YEAST.Quant.csv
# E HFD1_YEAST.Quant.csv
# 151 HIS2_YEAST.Quant.csv
# E HIS2_YEAST.Quant.csv
# 152 HMCS_YEAST.Quant.csv
# E HMCS_YEAST.Quant.csv
# 153 HMO1_YEAST.Quant.csv
# 25 0 0 0
# 154 HNT1_YEAST.Quant.csv
# 25 0 0 0
# 155 HS104_YEAST.Quant.csv
# 25 0 0 0
# 156 HSC82_YEAST.Quant.csv
# 25 0 0 0
# 157 HSP12_YEAST.Quant.csv
# 25 0 0 0
# 158 HSP26_YEAST.Quant.csv
# 25 0 0 0
# 159 HSP30_YEAST.Quant.csv
# 25 0 0 0
# 160 HSP31_YEAST.Quant.csv
# E HSP31_YEAST.Quant.csv
# 161 HSP60_YEAST.Quant.csv
# 25 0 0 0
# 162 HSP71_YEAST.Quant.csv
# 25 0 0 0
# 163 HSP72_YEAST.Quant.csv
# 25 0 0 0
# 164 HSP73_YEAST.Quant.csv
# 25 0 0 0
# 165 HSP74_YEAST.Quant.csv
# 25 0 0 0
# 166 HSP77_YEAST.Quant.csv
# 25 0 0 0
# 167 HSP78_YEAST.Quant.csv
# 25 0 0 0
# 168 HSP79_YEAST.Quant.csv
# 25 0 0 0
# 169 HSP7F_YEAST.Quant.csv
# 25 0 0 0
# 170 HSP82_YEAST.Quant.csv
# 25 0 0 0
# 171 HXKA_YEAST.Quant.csv
# 25 0 0 0
# 172 HXKB_YEAST.Quant.csv
# 25 0 0 0
# 173 HXKG_YEAST.Quant.csv
# 25 0 0 0
# 174 HXT6_YEAST.Quant.csv
# 25 0 0 0
# 175 IDH1_YEAST.Quant.csv
# 25 0 0 0
# 176 IDH2_YEAST.Quant.csv
# 25 0 0 0
# 177 IDHC_YEAST.Quant.csv
# 25 0 0 0
# 178 IDHP_YEAST.Quant.csv
# 25 0 0 0
# 179 IF2B_YEAST.Quant.csv
# E IF2B_YEAST.Quant.csv
# 180 IF2G_YEAST.Quant.csv
# E IF2G_YEAST.Quant.csv
# 181 IF4B_YEAST.Quant.csv
# E IF4B_YEAST.Quant.csv
# 182 IF4E_YEAST.Quant.csv
# 25 0 0 0
# 183 IF5A1_YEAST.Quant.csv
# 25 0 0 0
# 184 ILV3_YEAST.Quant.csv
# 25 0 0 0
# 185 ILV5_YEAST.Quant.csv
# 25 0 0 0
# 186 ILV6_YEAST.Quant.csv
# 25 0 0 0
# 187 ILVB_YEAST.Quant.csv
# E ILVB_YEAST.Quant.csv
# 188 IMB4_YEAST.Quant.csv
# 25 0 0 0
# 189 IMDH2_YEAST.Quant.csv
# 25 0 0 0
# 190 IMDH3_YEAST.Quant.csv
# 25 0 0 0
# 191 IMDH4_YEAST.Quant.csv
# E IMDH4_YEAST.Quant.csv
# 192 INO1_YEAST.Quant.csv
# 25 0 0 0
# 193 IPYR_YEAST.Quant.csv
# 25 0 0 0
# 194 ITR1_YEAST.Quant.csv
# E ITR1_YEAST.Quant.csv
# 195 KAR_YEAST.Quant.csv
# 25 0 0 0
# 196 KGUA_YEAST.Quant.csv
# 25 0 0 0
# 197 KPYK1_YEAST.Quant.csv
# 25 0 0 0
# 198 LCF1_YEAST.Quant.csv
# 25 0 0 0
# 199 LEU1_YEAST.Quant.csv
# 25 0 0 0
# 200 LSP1_YEAST.Quant.csv
# 25 0 0 0
# 201 MAS5_YEAST.Quant.csv
# E MAS5_YEAST.Quant.csv
# 202 MBF1_YEAST.Quant.csv
# 25 0 0 0
# 203 MDHC_YEAST.Quant.csv
# 25 0 0 0
# 204 MDHM_YEAST.Quant.csv
# 25 0 0 0
# 205 METE_YEAST.Quant.csv
# 25 0 0 0
# 206 METK1_YEAST.Quant.csv
# 25 0 0 0
# 207 MLC1_YEAST.Quant.csv
# 25 0 0 0
# 208 MLS1_YEAST.Quant.csv
# 25 0 0 0
# 209 MMF1_YEAST.Quant.csv
# 25 0 0 0
# 210 MPCP_YEAST.Quant.csv
# 25 0 0 0
# 211 MPG1_YEAST.Quant.csv
# 25 0 0 0
# 212 MPI_YEAST.Quant.csv
# 25 0 0 0
# 213 MRP8_YEAST.Quant.csv
# 25 0 0 0
# 214 MSC1_YEAST.Quant.csv
# E MSC1_YEAST.Quant.csv
# 215 NACA_YEAST.Quant.csv
# 25 0 0 0
# 216 NAP1_YEAST.Quant.csv
# E NAP1_YEAST.Quant.csv
# 217 NDI1_YEAST.Quant.csv
# E NDI1_YEAST.Quant.csv
# 218 NDK_YEAST.Quant.csv
# 25 0 0 0
# 219 NHP6A_YEAST.Quant.csv
# E NHP6A_YEAST.Quant.csv
# 220 NOP3_YEAST.Quant.csv
# 25 0 0 0
# 221 NPT1_YEAST.Quant.csv
# 25 0 0 0
# 222 ODC1_YEAST.Quant.csv
# E ODC1_YEAST.Quant.csv
# 223 ODO1_YEAST.Quant.csv
# 25 0 0 0
# 224 ODO2_YEAST.Quant.csv
# 25 0 0 0
# 225 ODP2_YEAST.Quant.csv
# 25 0 0 0
# 226 ODPA_YEAST.Quant.csv
# 25 0 0 0
# 227 ODPB_YEAST.Quant.csv
# 25 0 0 0
# 228 OLA1_YEAST.Quant.csv
# 25 0 0 0
# 229 OM45_YEAST.Quant.csv
# 25 0 0 0
# 230 OYE2_YEAST.Quant.csv
# 25 0 0 0
# 231 P5CR_YEAST.Quant.csv
# 25 0 0 0
# 232 PAA1_YEAST.Quant.csv
# 25 0 0 0
# 233 PABP_YEAST.Quant.csv
# 25 0 0 0
# 234 PCKA_YEAST.Quant.csv
# 25 0 0 0
# 235 PDC1_YEAST.Quant.csv
# 25 0 0 0
# 236 PDC5_YEAST.Quant.csv
# E PDC5_YEAST.Quant.csv
# 237 PDI_YEAST.Quant.csv
# 25 0 0 0
# 238 PET10_YEAST.Quant.csv
# 25 0 0 0
# 239 PFKA1_YEAST.Quant.csv
# 25 0 0 0
# 240 PFKA2_YEAST.Quant.csv
# 25 0 0 0
# 241 PGK_YEAST.Quant.csv
# 25 0 0 0
# 242 PGM2_YEAST.Quant.csv
# 25 0 0 0
# 243 PHSG_YEAST.Quant.csv
# 25 0 0 0
# 244 PIL1_YEAST.Quant.csv
# 25 0 0 0
# 245 PMA1_YEAST.Quant.csv
# 25 0 0 0
# 246 PMG1_YEAST.Quant.csv
# 25 0 0 0
# 247 PMM_YEAST.Quant.csv
# 25 0 0 0
# 248 PNC1_YEAST.Quant.csv
# 25 0 0 0
# 249 PP12_YEAST.Quant.csv
# 25 0 0 0
# 250 PP2A1_YEAST.Quant.csv
# 25 0 0 0
# 251 PPID_YEAST.Quant.csv
# 25 0 0 0
# 252 PRS8_YEAST.Quant.csv
# E PRS8_YEAST.Quant.csv
# 253 PRTB_YEAST.Quant.csv
# 25 0 0 0
# 254 PRX1_YEAST.Quant.csv
# 25 0 0 0
# 255 PSA1_YEAST.Quant.csv
# 25 0 0 0
# 256 PSA6_YEAST.Quant.csv
# E PSA6_YEAST.Quant.csv
# 257 PSA7_YEAST.Quant.csv
# E PSA7_YEAST.Quant.csv
# 258 PSB7_YEAST.Quant.csv
# E PSB7_YEAST.Quant.csv
# 259 PST2_YEAST.Quant.csv
# 25 0 0 0
# 260 PUR2_YEAST.Quant.csv
# 25 0 0 0
# 261 PUR4_YEAST.Quant.csv
# 25 0 0 0
# 262 PUR7_YEAST.Quant.csv
# 25 0 0 0
# 263 PUR8_YEAST.Quant.csv
# 25 0 0 0
# 264 PUR91_YEAST.Quant.csv
# 25 0 0 0
# 265 PUR92_YEAST.Quant.csv
# 25 0 0 0
# 266 PURA_YEAST.Quant.csv
# 25 0 0 0
# 267 PYC1_YEAST.Quant.csv
# 25 0 0 0
# 268 PYP1_YEAST.Quant.csv
# 25 0 0 0
# 269 PYR1_YEAST.Quant.csv
# 25 0 0 0
# 270 PYRD_YEAST.Quant.csv
# 25 0 0 0
# 271 QCR1_YEAST.Quant.csv
# 25 0 0 0
# 272 QCR2_YEAST.Quant.csv
# 25 0 0 0
# 273 QCR7_YEAST.Quant.csv
# 25 0 0 0
# 274 QOR_YEAST.Quant.csv
# E QOR_YEAST.Quant.csv
# 275 RDL1_YEAST.Quant.csv
# 25 0 0 0
# 276 RHO1_YEAST.Quant.csv
# 25 0 0 0
# 277 RIB4_YEAST.Quant.csv
# 25 0 0 0
# 278 RIM1_YEAST.Quant.csv
# 25 0 0 0
# 279 RIR2_YEAST.Quant.csv
# 25 0 0 0
# 280 RIR4_YEAST.Quant.csv
# 25 0 0 0
# 281 RL10_YEAST.Quant.csv
# 25 0 0 0
# 282 RL11A_YEAST.Quant.csv
# 25 0 0 0
# 283 RL11B_YEAST.Quant.csv
# 25 0 0 0
# 284 RL12A_YEAST.Quant.csv
# 25 0 0 0
# 285 RL13A_YEAST.Quant.csv
# E RL13A_YEAST.Quant.csv
# 286 RL14A_YEAST.Quant.csv
# 25 0 0 0
# 287 RL15A_YEAST.Quant.csv
# 25 0 0 0
# 288 RL16A_YEAST.Quant.csv
# 25 0 0 0
# 289 RL16B_YEAST.Quant.csv
# 25 0 0 0
# 290 RL17A_YEAST.Quant.csv
# 25 0 0 0
# 291 RL18A_YEAST.Quant.csv
# 25 0 0 0
# 292 RL19A_YEAST.Quant.csv
# E RL19A_YEAST.Quant.csv
# 293 RL1A_YEAST.Quant.csv
# 25 0 0 0
# 294 RL20A_YEAST.Quant.csv
# 25 0 0 0
# 295 RL22A_YEAST.Quant.csv
# 25 0 0 0
# 296 RL23A_YEAST.Quant.csv
# 25 0 0 0
# 297 RL25_YEAST.Quant.csv
# 25 0 0 0
# 298 RL26A_YEAST.Quant.csv
# 25 0 0 0
# 299 RL26B_YEAST.Quant.csv
# 25 0 0 0
# 300 RL27A_YEAST.Quant.csv
# 25 0 0 0
# 301 RL28_YEAST.Quant.csv
# 25 0 0 0
# 302 RL2A_YEAST.Quant.csv
# 25 0 0 0
# 303 RL30_YEAST.Quant.csv
# 25 0 0 0
# 304 RL31A_YEAST.Quant.csv
# E RL31A_YEAST.Quant.csv
# 305 RL33A_YEAST.Quant.csv
# 25 0 0 0
# 306 RL35A_YEAST.Quant.csv
# 25 0 0 0
# 307 RL36A_YEAST.Quant.csv
# 25 0 0 0
# 308 RL3_YEAST.Quant.csv
# 25 0 0 0
# 309 RL43A_YEAST.Quant.csv
# E RL43A_YEAST.Quant.csv
# 310 RL4A_YEAST.Quant.csv
# 25 0 0 0
# 311 RL5_YEAST.Quant.csv
# 25 0 0 0
# 312 RL6A_YEAST.Quant.csv
# 25 0 0 0
# 313 RL6B_YEAST.Quant.csv
# 25 0 0 0
# 314 RL7A_YEAST.Quant.csv
# 25 0 0 0
# 315 RL8A_YEAST.Quant.csv
# 25 0 0 0
# 316 RL8B_YEAST.Quant.csv
# 25 0 0 0
# 317 RL9A_YEAST.Quant.csv
# 25 0 0 0
# 318 RLA0_YEAST.Quant.csv
# 25 0 0 0
# 319 RLA2_YEAST.Quant.csv
# 25 0 0 0
# 320 RLA3_YEAST.Quant.csv
# E RLA3_YEAST.Quant.csv
# 321 RLA4_YEAST.Quant.csv
# 25 0 0 0
# 322 RPN1_YEAST.Quant.csv
# 25 0 0 0
# 323 RS10A_YEAST.Quant.csv
# 25 0 0 0
# 324 RS11A_YEAST.Quant.csv
# 25 0 0 0
# 325 RS12_YEAST.Quant.csv
# 25 0 0 0
# 326 RS13_YEAST.Quant.csv
# 25 0 0 0
# 327 RS15_YEAST.Quant.csv
# 25 0 0 0
# 328 RS16A_YEAST.Quant.csv
# 25 0 0 0
# 329 RS18A_YEAST.Quant.csv
# 25 0 0 0
# 330 RS19A_YEAST.Quant.csv
# 25 0 0 0
# 331 RS20_YEAST.Quant.csv
# 25 0 0 0
# 332 RS21A_YEAST.Quant.csv
# 25 0 0 0
# 333 RS22A_YEAST.Quant.csv
# 25 0 0 0
# 334 RS23A_YEAST.Quant.csv
# 25 0 0 0
# 335 RS24A_YEAST.Quant.csv
# 25 0 0 0
# 336 RS26A_YEAST.Quant.csv
# 25 0 0 0
# 337 RS27A_YEAST.Quant.csv
# 25 0 0 0
# 338 RS28A_YEAST.Quant.csv
# 25 0 0 0
# 339 RS2_YEAST.Quant.csv
# 25 0 0 0
# 340 RS31_YEAST.Quant.csv
# 25 0 0 0
# 341 RS3_YEAST.Quant.csv
# 25 0 0 0
# 342 RS4A_YEAST.Quant.csv
# 25 0 0 0
# 343 RS5_YEAST.Quant.csv
# 25 0 0 0
# 344 RS6A_YEAST.Quant.csv
# 25 0 0 0
# 345 RS7A_YEAST.Quant.csv
# 25 0 0 0
# 346 RS8A_YEAST.Quant.csv
# 25 0 0 0
# 347 RS9B_YEAST.Quant.csv
# 25 0 0 0
# 348 RUVB2_YEAST.Quant.csv
# E RUVB2_YEAST.Quant.csv
# 349 SAC1_YEAST.Quant.csv
# E SAC1_YEAST.Quant.csv
# 350 SAHH_YEAST.Quant.csv
# 25 0 0 0
# 351 SAM4_YEAST.Quant.csv
# E SAM4_YEAST.Quant.csv
# 352 SAR1_YEAST.Quant.csv
# E SAR1_YEAST.Quant.csv
# 353 SC160_YEAST.Quant.csv
# 25 0 0 0
# 354 SDHA_YEAST.Quant.csv
# 25 0 0 0
# 355 SDHB_YEAST.Quant.csv
# 25 0 0 0
# 356 SDHX_YEAST.Quant.csv
# E SDHX_YEAST.Quant.csv
# 357 SEC13_YEAST.Quant.csv
# E SEC13_YEAST.Quant.csv
# 358 SEC14_YEAST.Quant.csv
# 25 0 0 0
# 359 SEC4_YEAST.Quant.csv
# E SEC4_YEAST.Quant.csv
# 360 SERC_YEAST.Quant.csv
# E SERC_YEAST.Quant.csv
# 361 SFC1_YEAST.Quant.csv
# 25 0 0 0
# 362 SGT2_YEAST.Quant.csv
# 25 0 0 0
# 363 SIS1_YEAST.Quant.csv
# 25 0 0 0
# 364 SMT3_YEAST.Quant.csv
# 25 0 0 0
# 365 SODC_YEAST.Quant.csv
# 25 0 0 0
# 366 SODM_YEAST.Quant.csv
# 25 0 0 0
# 367 SSB1_YEAST.Quant.csv
# 25 0 0 0
# 368 SSB2_YEAST.Quant.csv
# 25 0 0 0
# 369 SSBP1_YEAST.Quant.csv
# 25 0 0 0
# 370 SSZ1_YEAST.Quant.csv
# 25 0 0 0
# 371 STI1_YEAST.Quant.csv
# 25 0 0 0
# 372 STM1_YEAST.Quant.csv
# 25 0 0 0
# 373 SUCA_YEAST.Quant.csv
# 25 0 0 0
# 374 SUCB_YEAST.Quant.csv
# 25 0 0 0
# 375 SUI1_YEAST.Quant.csv
# 25 0 0 0
# 376 SYA_YEAST.Quant.csv
# 25 0 0 0
# 377 SYDC_YEAST.Quant.csv
# 25 0 0 0
# 378 SYEC_YEAST.Quant.csv
# 25 0 0 0
# 379 SYFB_YEAST.Quant.csv
# 25 0 0 0
# 380 SYG_YEAST.Quant.csv
# 25 0 0 0
# 381 SYH_YEAST.Quant.csv
# 25 0 0 0
# 382 SYIC_YEAST.Quant.csv
# 25 0 0 0
# 383 SYKC_YEAST.Quant.csv
# 25 0 0 0
# 384 SYLC_YEAST.Quant.csv
# 25 0 0 0
# 385 SYNC_YEAST.Quant.csv
# 25 0 0 0
# 386 SYRC_YEAST.Quant.csv
# 25 0 0 0
# 387 SYSC_YEAST.Quant.csv
# 25 0 0 0
# 388 SYTC_YEAST.Quant.csv
# 25 0 0 0
# 389 SYV_YEAST.Quant.csv
# 25 0 0 0
# 390 SYYC_YEAST.Quant.csv
# E SYYC_YEAST.Quant.csv
# 391 TAL1_YEAST.Quant.csv
# 25 0 0 0
# 392 TBA1_YEAST.Quant.csv
# 25 0 0 0
# 393 TBB_YEAST.Quant.csv
# 25 0 0 0
# 394 TCPA_YEAST.Quant.csv
# E TCPA_YEAST.Quant.csv
# 395 TCPD_YEAST.Quant.csv
# E TCPD_YEAST.Quant.csv
# 396 TCTP_YEAST.Quant.csv
# 25 0 0 0
# 397 THIL_YEAST.Quant.csv
# 25 0 0 0
# 398 THRC_YEAST.Quant.csv
# 25 0 0 0
# 399 TIM9_YEAST.Quant.csv
# E TIM9_YEAST.Quant.csv
# 400 TKT1_YEAST.Quant.csv
# 25 0 0 0
# 401 TMA20_YEAST.Quant.csv
# E TMA20_YEAST.Quant.csv
# 402 TOM40_YEAST.Quant.csv
# E TOM40_YEAST.Quant.csv
# 403 TPIS_YEAST.Quant.csv
# 25 0 0 0
# 404 TPM1_YEAST.Quant.csv
# 25 0 0 0
# 405 TPS1_YEAST.Quant.csv
# 25 0 0 0
# 406 TRP_YEAST.Quant.csv
# 25 0 0 0
# 407 TRX1_YEAST.Quant.csv
# 25 0 0 0
# 408 TRX2_YEAST.Quant.csv
# 25 0 0 0
# 409 TRXB1_YEAST.Quant.csv
# 25 0 0 0
# 410 TSA1_YEAST.Quant.csv
# 25 0 0 0
# 411 TSL1_YEAST.Quant.csv
# 25 0 0 0
# 412 UBA1_YEAST.Quant.csv
# 25 0 0 0
# 413 UCRI_YEAST.Quant.csv
# 25 0 0 0
# 414 UGPA1_YEAST.Quant.csv
# 25 0 0 0
# 415 URA7_YEAST.Quant.csv
# E URA7_YEAST.Quant.csv
# 416 VATA_YEAST.Quant.csv
# 25 0 0 0
# 417 VATB_YEAST.Quant.csv
# 25 0 0 0
# 418 VATC_YEAST.Quant.csv
# E VATC_YEAST.Quant.csv
# 419 VATE_YEAST.Quant.csv
# 25 0 0 0
# 420 VATG_YEAST.Quant.csv
# E VATG_YEAST.Quant.csv
# 421 VATH_YEAST.Quant.csv
# E VATH_YEAST.Quant.csv
# 422 VDAC1_YEAST.Quant.csv
# 25 0 0 0
# 423 VPS1_YEAST.Quant.csv
# 25 0 0 0
# 424 VPS21_YEAST.Quant.csv
# E VPS21_YEAST.Quant.csv
# 425 WTM1_YEAST.Quant.csv
# 25 0 0 0
# 426 YCP4_YEAST.Quant.csv
# 25 0 0 0
# 427 YGP1_YEAST.Quant.csv
# 25 0 0 0
# 428 YHI0_YEAST.Quant.csv
# 25 0 0 0
# 429 YL179_YEAST.Quant.csv
# E YL179_YEAST.Quant.csv
# 430 YN034_YEAST.Quant.csv
# 25 0 0 0
# 431 YNN4_YEAST.Quant.csv
# 25 0 0 0
# 432 YNU8_YEAST.Quant.csv
# 25 0 0 0
# 433 YP010_YEAST.Quant.csv
# E YP010_YEAST.Quant.csv
# 434 YP225_YEAST.Quant.csv
# 25 0 0 0
# 435 YPT1_YEAST.Quant.csv
# E YPT1_YEAST.Quant.csv
# 436 YPT31_YEAST.Quant.csv
# E YPT31_YEAST.Quant.csv
# 437 YPT7_YEAST.Quant.csv
# E YPT7_YEAST.Quant.csv
# 438 YRB1_YEAST.Quant.csv
# E YRB1_YEAST.Quant.csv
# 439 ZEO1_YEAST.Quant.csv
# 25 0 0 0
# 440 ZPR1_YEAST.Quant.csv
# 25 0 0 0
# 441 ZUO1_YEAST.Quant.csv
# 25 0 0 0

# %%
ZEROIONSCORE_WITHVALUE
# Out:
# {}

# %%
ndk
# Out:
# {16: 1}

# %%
sum(ndk.values())
# Out:
# 1

# %%
proteincount
# Out:
# 359

# %%
dictpept
# Out:
# {0: 1574,
#  1: 1574,
#  2: 1574,
#  3: 1574,
#  4: 1574,
#  5: 1574,
#  6: 1574,
#  7: 1574,
#  8: 1574,
#  9: 1574,
#  10: 1574,
#  11: 1574,
#  12: 1574,
#  13: 1574,
#  14: 1574,
#  15: 1574,
#  16: 1574,
#  17: 1574,
#  18: 1574,
#  19: 1574}
