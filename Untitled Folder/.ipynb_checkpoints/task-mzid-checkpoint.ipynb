# %%
import os
import pandas as pd
import numpy as np

# %%
filepath="C:\\Users\\hmdebern.UTMB-USERS-M\\Desktop\\human_yeast_data_11\\"
files=os.listdir(filepath)
files=[x for x in files if "YEAST.Quant.csv" in x]
print(len(files))
# Out:
# 408

# %%
# # tt=pd.read_csv(filepath+files[files.index('ARGI_YEAST.Quant.csv') ],skiprows=3,index_col=False) #  ,header=None,
# tt
# # len(expriments)
# pd.read_csv(filepath+files[files.index('ARGI_YEAST.Quant.csv') ],index_col=False,skiprows=1)

# %%
TN=0
FN=0
FP=0
TP=0
start=12 
elu_window=0

temp_fillalldata=pd.read_csv(filepath+files[files.index('6PGD1_YEAST.Quant.csv') ],skiprows=3,index_col=False)  
temp_fillalldata.fillna(-500)

for row in range(temp_fillalldata.shape[0]):#temp_fillalldata.shape[0]
    
    expriments=[]
    for i in range(40):
        try:
            expriments.append(list(temp_fillalldata.iloc[row,start +i*16:(start+16)+ i*16].astype('float')))
        except:
            expriments.append([-500]*16)
            
        if(i>19 and (expriments[-1][1])>0 and (sum(expriments[-1][5:11])>0) ): # check ionscore, to compute elution window 
            elu_window=abs(expriments[-1][11]-expriments[-1][12])

    for i in range(20):
        temp=expriments[i]
        isotopsum=sum(temp[5:11])

        if( isotopsum ==0 or isotopsum < 1E5 or abs(temp[11]-temp[12])<= 0.5*elu_window  ): #
            TN+=1
        elif(isotopsum>0):
            FP+=1

print(TN,FP,TP,FN)
# Out:
# 211 29 0 0

# %%
TN=0
FN=0
FP=0
TP=0
start=12 

for f in range(len(files)):#
    try:
        print(f,files[f])
        
        elu_window=0
        
        #read quant file
        try:
            temp_fillalldata=pd.read_csv(filepath+files[f],skiprows=3,index_col=False)  
            temp_fillalldata.fillna(-500)
        except:
            temp_fillalldata=pd.read_csv(filepath+files[files.index('ARGI_YEAST.Quant.csv') ],index_col=False,skiprows=1)
            temp_fillalldata.fillna(-500)

        for row in range(temp_fillalldata.shape[0]):#temp_fillalldata.shape[0]

            expriments=[]
            for i in range(40):
                try:
                    expriments.append(list(temp_fillalldata.iloc[row,start +i*16:(start+16)+ i*16].astype('float')))
                except:
                    expriments.append([-500]*16)

                if(i>19 and (expriments[-1][1])>0 and (sum(expriments[-1][5:11])>0) ): # check ionscore, to compute elution window 
                    elu_window=abs(expriments[-1][11]-expriments[-1][12])

            for i in range(20):
                temp=expriments[i]
                isotopsum=sum(temp[5:11])

                if( isotopsum ==0 or isotopsum < 1E5 or abs(temp[11]-temp[12])<= 0.5*elu_window  ): #
                    TN+=1
                elif(isotopsum>0):
                    FP+=1

        print(TN,FP,TP,FN) 
#         print("\t\t"+ (100*FP/(TN+FP)))
    except:
        print("E",files[f])
# Out:
# 0 6PGD1_YEAST.Quant.csv
# 211 29 0 0
# 1 AATC_YEAST.Quant.csv
# 291 29 0 0
# 2 ABF2_YEAST.Quant.csv
# 305 35 0 0
# 3 ABP1_YEAST.Quant.csv
# 425 35 0 0
# 4 ACAC_YEAST.Quant.csv
# 505 35 0 0
# 5 ACBP_YEAST.Quant.csv
# 545 35 0 0
# 6 ACEA_YEAST.Quant.csv
# 718 42 0 0
# 7 ACH1_YEAST.Quant.csv
# 976 44 0 0
# 8 ACON_YEAST.Quant.csv
# 1254 66 0 0
# 9 ACS1_YEAST.Quant.csv
# 1434 66 0 0
# 10 ACT_YEAST.Quant.csv
# 1610 90 0 0
# 11 ADH1_YEAST.Quant.csv
# 1847 113 0 0
# 12 ADH2_YEAST.Quant.csv
# 1947 113 0 0
# 13 ADH3_YEAST.Quant.csv
# 2027 113 0 0
# 14 ADH6_YEAST.Quant.csv
# 2087 113 0 0
# 15 ADK_YEAST.Quant.csv
# 2224 116 0 0
# 16 ADT2_YEAST.Quant.csv
# 2344 116 0 0
# 17 ADY2_YEAST.Quant.csv
# 2364 116 0 0
# 18 AHP1_YEAST.Quant.csv
# 2464 116 0 0
# 19 AIM2_YEAST.Quant.csv
# 2484 116 0 0
# 20 ALDH4_YEAST.Quant.csv
# 2724 116 0 0
# 21 ALDH6_YEAST.Quant.csv
# 3060 120 0 0
# 22 ALF_YEAST.Quant.csv
# 3419 121 0 0
# 23 AMPL_YEAST.Quant.csv
# 3519 121 0 0
# 24 APE2_YEAST.Quant.csv
# 3559 121 0 0
# 25 ARA1_YEAST.Quant.csv
# 3617 123 0 0
# 26 ARC1_YEAST.Quant.csv
# 3677 123 0 0
# 27 ARF1_YEAST.Quant.csv
# 3796 124 0 0
# 28 ARF2_YEAST.Quant.csv
# 3816 124 0 0
# 29 ARGI_YEAST.Quant.csv
# 3836 124 0 0
# 30 ARO8_YEAST.Quant.csv
# 4052 128 0 0
# 31 ARO9_YEAST.Quant.csv
# 4052 128 0 0
# 32 AROC_YEAST.Quant.csv
# 4072 128 0 0
# 33 AROF_YEAST.Quant.csv
# 4092 128 0 0
# 34 AROG_YEAST.Quant.csv
# 4132 128 0 0
# 35 ARP2_YEAST.Quant.csv
# 4191 129 0 0
# 36 ASNS1_YEAST.Quant.csv
# 4270 130 0 0
# 37 ASNS2_YEAST.Quant.csv
# 4290 130 0 0
# 38 ATIF_YEAST.Quant.csv
# 4310 130 0 0
# 39 ATO2_YEAST.Quant.csv
# 4310 130 0 0
# 40 ATP7_YEAST.Quant.csv
# 4330 130 0 0
# 41 ATPA_YEAST.Quant.csv
# 4517 143 0 0
# 42 ATPB_YEAST.Quant.csv
# 4735 145 0 0
# 43 ATPD_YEAST.Quant.csv
# 4755 145 0 0
# 44 ATPF_YEAST.Quant.csv
# 4834 146 0 0
# 45 ATPG_YEAST.Quant.csv
# 4870 150 0 0
# 46 ATPO_YEAST.Quant.csv
# 4970 150 0 0
# 47 BCA1_YEAST.Quant.csv
# 4970 150 0 0
# 48 BCA2_YEAST.Quant.csv
# 4990 150 0 0
# 49 BFR1_YEAST.Quant.csv
# 5029 151 0 0
# 50 BGL2_YEAST.Quant.csv
# 5049 151 0 0
# 51 BIP_YEAST.Quant.csv
# 5160 200 0 0
# 52 BMH1_YEAST.Quant.csv
# 5260 200 0 0
# 53 BMH2_YEAST.Quant.csv
# 5280 200 0 0
# 54 C1TC_YEAST.Quant.csv
# 5340 200 0 0
# 55 CACM_YEAST.Quant.csv
# 5380 200 0 0
# 56 CACP_YEAST.Quant.csv
# 5439 201 0 0
# 57 CALM_YEAST.Quant.csv
# 5459 201 0 0
# 58 CAP_YEAST.Quant.csv
# 5539 201 0 0
# 59 CARP_YEAST.Quant.csv
# 5650 210 0 0
# 60 CBPS_YEAST.Quant.csv
# 5670 210 0 0
# 61 CBPY_YEAST.Quant.csv
# 5690 210 0 0
# 62 CBS_YEAST.Quant.csv
# 5810 210 0 0
# 63 CCPR_YEAST.Quant.csv
# 5890 210 0 0
# 64 CDC48_YEAST.Quant.csv
# 6045 255 0 0
# 65 CH10_YEAST.Quant.csv
# 6125 255 0 0
# 66 CISY1_YEAST.Quant.csv
# 6360 260 0 0
# 67 CLC1_YEAST.Quant.csv
# 6380 260 0 0
# 68 CLH_YEAST.Quant.csv
# 6380 260 0 0
# 69 CLU_YEAST.Quant.csv
# 6420 260 0 0
# 70 COFI_YEAST.Quant.csv
# 6497 263 0 0
# 71 COX12_YEAST.Quant.csv
# 6517 263 0 0
# 72 COX2_YEAST.Quant.csv
# 6537 263 0 0
# 73 COX4_YEAST.Quant.csv
# 6617 263 0 0
# 74 CY1_YEAST.Quant.csv
# 6637 263 0 0
# 75 CYC1_YEAST.Quant.csv
# 6677 263 0 0
# 76 CYPC_YEAST.Quant.csv
# 6697 263 0 0
# 77 CYPD_YEAST.Quant.csv
# 6754 266 0 0
# 78 CYPH_YEAST.Quant.csv
# 6813 287 0 0
# 79 CYS3_YEAST.Quant.csv
# 6928 292 0 0
# 80 DAK1_YEAST.Quant.csv
# 6988 292 0 0
# 81 DCPS_YEAST.Quant.csv
# 7008 292 0 0
# 82 DHAS_YEAST.Quant.csv
# 7028 292 0 0
# 83 DHE2_YEAST.Quant.csv
# 7068 292 0 0
# 84 DHE4_YEAST.Quant.csv
# 7257 303 0 0
# 85 DHE5_YEAST.Quant.csv
# 7277 303 0 0
# 86 DHOM_YEAST.Quant.csv
# 7414 306 0 0
# 87 DLD1_YEAST.Quant.csv
# 7434 306 0 0
# 88 DLDH_YEAST.Quant.csv
# 7693 307 0 0
# 89 DPM1_YEAST.Quant.csv
# 7753 307 0 0
# 90 DUG1_YEAST.Quant.csv
# 7853 307 0 0
# 91 EF1A_YEAST.Quant.csv
# 8134 326 0 0
# 92 EF1B_YEAST.Quant.csv
# 8169 331 0 0
# 93 EF1G1_YEAST.Quant.csv
# 8249 331 0 0
# 94 EF1G2_YEAST.Quant.csv
# 8366 334 0 0
# 95 EF2_YEAST.Quant.csv
# 8859 361 0 0
# 96 EF3A_YEAST.Quant.csv
# 9367 373 0 0
# 97 EFTU_YEAST.Quant.csv
# 9424 376 0 0
# 98 EIF3J_YEAST.Quant.csv
# 9444 376 0 0
# 99 EMI2_YEAST.Quant.csv
# 9484 376 0 0
# 100 ENO1_YEAST.Quant.csv
# 9930 390 0 0
# 101 ENO2_YEAST.Quant.csv
# 10209 391 0 0
# 102 ERF1_YEAST.Quant.csv
# 10229 391 0 0
# 103 ERF3_YEAST.Quant.csv
# 10268 392 0 0
# 104 ERG6_YEAST.Quant.csv
# 10288 392 0 0
# 105 ERR1_YEAST.Quant.csv
# 10288 392 0 0
# 106 F16P_YEAST.Quant.csv
# 10492 408 0 0
# 107 FAS1_YEAST.Quant.csv
# 10746 414 0 0
# 108 FAS2_YEAST.Quant.csv
# 10965 455 0 0
# 109 FAT2_YEAST.Quant.csv
# 11043 457 0 0
# 110 FHP_YEAST.Quant.csv
# 11103 457 0 0
# 111 FIMB_YEAST.Quant.csv
# 11209 471 0 0
# 112 FKBP3_YEAST.Quant.csv
# 11229 471 0 0
# 113 FKBP_YEAST.Quant.csv
# 11309 471 0 0
# 114 FPPS_YEAST.Quant.csv
# 11369 471 0 0
# 115 FRDS_YEAST.Quant.csv
# 11389 471 0 0
# 116 FUMH_YEAST.Quant.csv
# 11429 471 0 0
# 117 G3P1_YEAST.Quant.csv
# 11743 497 0 0
# 118 G3P2_YEAST.Quant.csv
# 11907 513 0 0
# 119 G3P3_YEAST.Quant.csv
# 12067 513 0 0
# 120 G6PI_YEAST.Quant.csv
# 12386 514 0 0
# 121 GAS1_YEAST.Quant.csv
# 12406 514 0 0
# 122 GBLP_YEAST.Quant.csv
# 12465 515 0 0
# 123 GDI1_YEAST.Quant.csv
# 12488 532 0 0
# 124 GLNA_YEAST.Quant.csv
# 12568 532 0 0
# 125 GLRX1_YEAST.Quant.csv
# 12608 532 0 0
# 126 GLRX2_YEAST.Quant.csv
# 12628 532 0 0
# 127 GLT1_YEAST.Quant.csv
# 12668 532 0 0
# 128 GLYC_YEAST.Quant.csv
# 12768 532 0 0
# 129 GLYM_YEAST.Quant.csv
# 12782 538 0 0
# 130 GPD1_YEAST.Quant.csv
# 12922 538 0 0
# 131 GPDM_YEAST.Quant.csv
# 12982 538 0 0
# 132 GPP1_YEAST.Quant.csv
# 13013 547 0 0
# 133 GPX3_YEAST.Quant.csv
# 13033 547 0 0
# 134 GRE1_YEAST.Quant.csv
# 13033 547 0 0
# 135 GSHR_YEAST.Quant.csv
# 13077 563 0 0
# 136 GUAA_YEAST.Quant.csv
# 13097 563 0 0
# 137 GVP36_YEAST.Quant.csv
# 13197 563 0 0
# 138 H2A1_YEAST.Quant.csv
# 13217 563 0 0
# 139 H2B1_YEAST.Quant.csv
# 13257 583 0 0
# 140 H4_YEAST.Quant.csv
# 13317 583 0 0
# 141 HBT1_YEAST.Quant.csv
# 13317 583 0 0
# 142 HIS2_YEAST.Quant.csv
# 13337 583 0 0
# 143 HMCS_YEAST.Quant.csv
# 13357 583 0 0
# 144 HMO1_YEAST.Quant.csv
# 13397 583 0 0
# 145 HNT1_YEAST.Quant.csv
# 13437 583 0 0
# 146 HS104_YEAST.Quant.csv
# 13738 602 0 0
# 147 HSC82_YEAST.Quant.csv
# 14133 607 0 0
# 148 HSP12_YEAST.Quant.csv
# 14168 612 0 0
# 149 HSP26_YEAST.Quant.csv
# 14286 614 0 0
# 150 HSP30_YEAST.Quant.csv
# 14319 621 0 0
# 151 HSP60_YEAST.Quant.csv
# 14615 625 0 0
# 152 HSP71_YEAST.Quant.csv
# 15111 649 0 0
# 153 HSP72_YEAST.Quant.csv
# 15249 651 0 0
# 154 HSP73_YEAST.Quant.csv
# 15249 651 0 0
# 155 HSP74_YEAST.Quant.csv
# 15328 652 0 0
# 156 HSP77_YEAST.Quant.csv
# 15626 654 0 0
# 157 HSP78_YEAST.Quant.csv
# 15646 674 0 0
# 158 HSP79_YEAST.Quant.csv
# 15669 691 0 0
# 159 HSP7F_YEAST.Quant.csv
# 15869 691 0 0
# 160 HSP82_YEAST.Quant.csv
# 15949 691 0 0
# 161 HXKA_YEAST.Quant.csv
# 16165 735 0 0
# 162 HXKB_YEAST.Quant.csv
# 16401 739 0 0
# 163 HXKG_YEAST.Quant.csv
# 16547 773 0 0
# 164 HXT6_YEAST.Quant.csv
# 16622 778 0 0
# 165 IDH1_YEAST.Quant.csv
# 16730 790 0 0
# 166 IDH2_YEAST.Quant.csv
# 16883 797 0 0
# 167 IDHC_YEAST.Quant.csv
# 17043 797 0 0
# 168 IDHP_YEAST.Quant.csv
# 17141 799 0 0
# 169 IF2B_YEAST.Quant.csv
# 17158 802 0 0
# 170 IF4B_YEAST.Quant.csv
# 17178 802 0 0
# 171 IF4E_YEAST.Quant.csv
# 17178 802 0 0
# 172 IF5A1_YEAST.Quant.csv
# 17257 803 0 0
# 173 ILV3_YEAST.Quant.csv
# 17397 803 0 0
# 174 ILV5_YEAST.Quant.csv
# 17690 810 0 0
# 175 ILV6_YEAST.Quant.csv
# 17690 810 0 0
# 176 ILVB_YEAST.Quant.csv
# 17710 810 0 0
# 177 IMB4_YEAST.Quant.csv
# 17762 818 0 0
# 178 IMDH3_YEAST.Quant.csv
# 17895 825 0 0
# 179 IMDH4_YEAST.Quant.csv
# 17912 828 0 0
# 180 INO1_YEAST.Quant.csv
# 17995 845 0 0
# 181 IPYR_YEAST.Quant.csv
# 18175 845 0 0
# 182 KAR_YEAST.Quant.csv
# 18195 845 0 0
# 183 KPYK1_YEAST.Quant.csv
# 18644 856 0 0
# 184 LCF1_YEAST.Quant.csv
# 18724 856 0 0
# 185 LEU1_YEAST.Quant.csv
# 18764 856 0 0
# 186 LSP1_YEAST.Quant.csv
# 18864 856 0 0
# 187 MAS5_YEAST.Quant.csv
# 18884 856 0 0
# 188 MBF1_YEAST.Quant.csv
# 18924 856 0 0
# 189 MDHC_YEAST.Quant.csv
# 19040 860 0 0
# 190 MDHM_YEAST.Quant.csv
# 19246 874 0 0
# 191 METE_YEAST.Quant.csv
# 19361 879 0 0
# 192 METK1_YEAST.Quant.csv
# 19405 895 0 0
# 193 MLC1_YEAST.Quant.csv
# 19463 897 0 0
# 194 MLS1_YEAST.Quant.csv
# 19692 908 0 0
# 195 MMF1_YEAST.Quant.csv
# 19772 908 0 0
# 196 MPCP_YEAST.Quant.csv
# 19932 908 0 0
# 197 MPG1_YEAST.Quant.csv
# 20072 908 0 0
# 198 MPI_YEAST.Quant.csv
# 20092 908 0 0
# 199 MSC1_YEAST.Quant.csv
# 20112 908 0 0
# 200 NACA_YEAST.Quant.csv
# 20192 908 0 0
# 201 NAP1_YEAST.Quant.csv
# 20212 908 0 0
# 202 NDK_YEAST.Quant.csv
# 20305 915 0 0
# 203 NHP6A_YEAST.Quant.csv
# 20325 915 0 0
# 204 NOP3_YEAST.Quant.csv
# 20365 915 0 0
# 205 NPT1_YEAST.Quant.csv
# 20405 915 0 0
# 206 ODO1_YEAST.Quant.csv
# 20714 926 0 0
# 207 ODO2_YEAST.Quant.csv
# 20834 926 0 0
# 208 ODP2_YEAST.Quant.csv
# 20874 926 0 0
# 209 ODPA_YEAST.Quant.csv
# 21002 938 0 0
# 210 ODPB_YEAST.Quant.csv
# 21102 938 0 0
# 211 OLA1_YEAST.Quant.csv
# 21202 938 0 0
# 212 OM45_YEAST.Quant.csv
# 21301 959 0 0
# 213 OYE2_YEAST.Quant.csv
# 21499 961 0 0
# 214 P5CR_YEAST.Quant.csv
# 21519 961 0 0
# 215 PAA1_YEAST.Quant.csv
# 21539 961 0 0
# 216 PABP_YEAST.Quant.csv
# 21678 962 0 0
# 217 PCKA_YEAST.Quant.csv
# 22192 968 0 0
# 218 PDC1_YEAST.Quant.csv
# 22616 984 0 0
# 219 PDI_YEAST.Quant.csv
# 22734 986 0 0
# 220 PET10_YEAST.Quant.csv
# 22754 986 0 0
# 221 PFKA1_YEAST.Quant.csv
# 23180 1000 0 0
# 222 PFKA2_YEAST.Quant.csv
# 23371 1009 0 0
# 223 PGK_YEAST.Quant.csv
# 23764 1016 0 0
# 224 PGM2_YEAST.Quant.csv
# 23962 1018 0 0
# 225 PHSG_YEAST.Quant.csv
# 24068 1032 0 0
# 226 PIL1_YEAST.Quant.csv
# 24168 1032 0 0
# 227 PMA1_YEAST.Quant.csv
# 24428 1032 0 0
# 228 PMG1_YEAST.Quant.csv
# 24621 1039 0 0
# 229 PMM_YEAST.Quant.csv
# 24700 1040 0 0
# 230 PNC1_YEAST.Quant.csv
# 24760 1040 0 0
# 231 PP12_YEAST.Quant.csv
# 24820 1040 0 0
# 232 PP2A1_YEAST.Quant.csv
# 24850 1070 0 0
# 233 PPID_YEAST.Quant.csv
# 24910 1070 0 0
# 234 PRS8_YEAST.Quant.csv
# 24930 1070 0 0
# 235 PRTB_YEAST.Quant.csv
# 24983 1077 0 0
# 236 PRX1_YEAST.Quant.csv
# 25102 1078 0 0
# 237 PSA1_YEAST.Quant.csv
# 25102 1078 0 0
# 238 PST2_YEAST.Quant.csv
# 25202 1078 0 0
# 239 PUR2_YEAST.Quant.csv
# 25202 1078 0 0
# 240 PUR4_YEAST.Quant.csv
# 25242 1078 0 0
# 241 PUR7_YEAST.Quant.csv
# 25342 1078 0 0
# 242 PUR8_YEAST.Quant.csv
# 25461 1079 0 0
# 243 PUR92_YEAST.Quant.csv
# 25570 1090 0 0
# 244 PURA_YEAST.Quant.csv
# 25690 1090 0 0
# 245 PYC1_YEAST.Quant.csv
# 25949 1091 0 0
# 246 PYP1_YEAST.Quant.csv
# 26009 1091 0 0
# 247 PYR1_YEAST.Quant.csv
# 26912 1108 0 0
# 248 PYRD_YEAST.Quant.csv
# 26972 1108 0 0
# 249 QCR1_YEAST.Quant.csv
# 27111 1109 0 0
# 250 QCR2_YEAST.Quant.csv
# 27327 1113 0 0
# 251 QCR7_YEAST.Quant.csv
# 27387 1113 0 0
# 252 RDL1_YEAST.Quant.csv
# 27387 1113 0 0
# 253 RHO1_YEAST.Quant.csv
# 27414 1146 0 0
# 254 RIB4_YEAST.Quant.csv
# 27474 1146 0 0
# 255 RIM1_YEAST.Quant.csv
# 27494 1146 0 0
# 256 RIR2_YEAST.Quant.csv
# 27694 1146 0 0
# 257 RIR4_YEAST.Quant.csv
# 27830 1150 0 0
# 258 RL10_YEAST.Quant.csv
# 27887 1153 0 0
# 259 RL11A_YEAST.Quant.csv
# 27887 1153 0 0
# 260 RL11B_YEAST.Quant.csv
# 27947 1153 0 0
# 261 RL12A_YEAST.Quant.csv
# 28008 1172 0 0
# 262 RL13A_YEAST.Quant.csv
# 28028 1172 0 0
# 263 RL14A_YEAST.Quant.csv
# 28067 1173 0 0
# 264 RL15A_YEAST.Quant.csv
# 28144 1176 0 0
# 265 RL16A_YEAST.Quant.csv
# 28164 1176 0 0
# 266 RL16B_YEAST.Quant.csv
# 28244 1176 0 0
# 267 RL17A_YEAST.Quant.csv
# 28304 1176 0 0
# 268 RL18A_YEAST.Quant.csv
# 28364 1176 0 0
# 269 RL19A_YEAST.Quant.csv
# 28384 1176 0 0
# 270 RL1A_YEAST.Quant.csv
# 28439 1181 0 0
# 271 RL20A_YEAST.Quant.csv
# 28479 1181 0 0
# 272 RL22A_YEAST.Quant.csv
# 28539 1181 0 0
# 273 RL23A_YEAST.Quant.csv
# 28581 1199 0 0
# 274 RL25_YEAST.Quant.csv
# 28621 1199 0 0
# 275 RL26A_YEAST.Quant.csv
# 28660 1200 0 0
# 276 RL27A_YEAST.Quant.csv
# 28760 1200 0 0
# 277 RL28_YEAST.Quant.csv
# 28820 1200 0 0
# 278 RL2A_YEAST.Quant.csv
# 28860 1200 0 0
# 279 RL30_YEAST.Quant.csv
# 28940 1200 0 0
# 280 RL31A_YEAST.Quant.csv
# 28960 1200 0 0
# 281 RL33A_YEAST.Quant.csv
# 28998 1202 0 0
# 282 RL35A_YEAST.Quant.csv
# 29058 1202 0 0
# 283 RL36A_YEAST.Quant.csv
# 29110 1210 0 0
# 284 RL3_YEAST.Quant.csv
# 29230 1210 0 0
# 285 RL43A_YEAST.Quant.csv
# 29250 1210 0 0
# 286 RL4A_YEAST.Quant.csv
# 29359 1221 0 0
# 287 RL5_YEAST.Quant.csv
# 29458 1222 0 0
# 288 RL6A_YEAST.Quant.csv
# 29538 1222 0 0
# 289 RL6B_YEAST.Quant.csv
# 29618 1222 0 0
# 290 RL7A_YEAST.Quant.csv
# 29682 1238 0 0
# 291 RL8A_YEAST.Quant.csv
# 29762 1238 0 0
# 292 RL8B_YEAST.Quant.csv
# 29842 1238 0 0
# 293 RL9A_YEAST.Quant.csv
# 29842 1238 0 0
# 294 RLA0_YEAST.Quant.csv
# 29902 1238 0 0
# 295 RLA2_YEAST.Quant.csv
# 29982 1238 0 0
# 296 RLA3_YEAST.Quant.csv
# 30002 1238 0 0
# 297 RLA4_YEAST.Quant.csv
# 30061 1239 0 0
# 298 RS10A_YEAST.Quant.csv
# 30121 1239 0 0
# 299 RS11A_YEAST.Quant.csv
# 30200 1240 0 0
# 300 RS12_YEAST.Quant.csv
# 30200 1240 0 0
# 301 RS13_YEAST.Quant.csv
# 30280 1240 0 0
# 302 RS15_YEAST.Quant.csv
# 30338 1242 0 0
# 303 RS16A_YEAST.Quant.csv
# 30398 1242 0 0
# 304 RS18A_YEAST.Quant.csv
# 30476 1244 0 0
# 305 RS19A_YEAST.Quant.csv
# 30536 1244 0 0
# 306 RS20_YEAST.Quant.csv
# 30596 1244 0 0
# 307 RS21A_YEAST.Quant.csv
# 30635 1245 0 0
# 308 RS22A_YEAST.Quant.csv
# 30735 1245 0 0
# 309 RS23A_YEAST.Quant.csv
# 30792 1248 0 0
# 310 RS24A_YEAST.Quant.csv
# 30792 1248 0 0
# 311 RS26A_YEAST.Quant.csv
# 30825 1255 0 0
# 312 RS27A_YEAST.Quant.csv
# 30865 1255 0 0
# 313 RS28A_YEAST.Quant.csv
# 30886 1274 0 0
# 314 RS2_YEAST.Quant.csv
# 30986 1274 0 0
# 315 RS31_YEAST.Quant.csv
# 31026 1274 0 0
# 316 RS3_YEAST.Quant.csv
# 31180 1280 0 0
# 317 RS4A_YEAST.Quant.csv
# 31239 1281 0 0
# 318 RS5_YEAST.Quant.csv
# 31321 1299 0 0
# 319 RS6A_YEAST.Quant.csv
# 31389 1311 0 0
# 320 RS7A_YEAST.Quant.csv
# 31429 1311 0 0
# 321 RS8A_YEAST.Quant.csv
# 31494 1326 0 0
# 322 RS9B_YEAST.Quant.csv
# 31520 1340 0 0
# 323 SAC1_YEAST.Quant.csv
# 31540 1340 0 0
# 324 SAHH_YEAST.Quant.csv
# 31600 1340 0 0
# 325 SAM4_YEAST.Quant.csv
# 31614 1346 0 0
# 326 SC160_YEAST.Quant.csv
# 31679 1361 0 0
# 327 SDHA_YEAST.Quant.csv
# 31786 1374 0 0
# 328 SDHB_YEAST.Quant.csv
# 31902 1378 0 0
# 329 SEC13_YEAST.Quant.csv
# 31922 1378 0 0
# 330 SEC14_YEAST.Quant.csv
# 31982 1378 0 0
# 331 SERC_YEAST.Quant.csv
# 32000 1380 0 0
# 332 SFC1_YEAST.Quant.csv
# 32020 1380 0 0
# 333 SGT2_YEAST.Quant.csv
# 32060 1380 0 0
# 334 SIS1_YEAST.Quant.csv
# 32213 1387 0 0
# 335 SMT3_YEAST.Quant.csv
# 32253 1387 0 0
# 336 SODC_YEAST.Quant.csv
# 32293 1387 0 0
# 337 SODM_YEAST.Quant.csv
# 32429 1391 0 0
# 338 SPEE_YEAST.Quant.csv
# 32469 1391 0 0
# 339 SSB1_YEAST.Quant.csv
# 32892 1408 0 0
# 340 SSB2_YEAST.Quant.csv
# 32932 1408 0 0
# 341 SSBP1_YEAST.Quant.csv
# 32952 1408 0 0
# 342 SSZ1_YEAST.Quant.csv
# 33147 1413 0 0
# 343 STI1_YEAST.Quant.csv
# 33287 1413 0 0
# 344 STM1_YEAST.Quant.csv
# 33347 1413 0 0
# 345 SUCA_YEAST.Quant.csv
# 33426 1414 0 0
# 346 SUCB_YEAST.Quant.csv
# 33457 1423 0 0
# 347 SUI1_YEAST.Quant.csv
# 33497 1423 0 0
# 348 SYA_YEAST.Quant.csv
# 33617 1423 0 0
# 349 SYDC_YEAST.Quant.csv
# 33832 1428 0 0
# 350 SYEC_YEAST.Quant.csv
# 34011 1429 0 0
# 351 SYFB_YEAST.Quant.csv
# 34060 1440 0 0
# 352 SYG_YEAST.Quant.csv
# 34220 1440 0 0
# 353 SYH_YEAST.Quant.csv
# 34240 1440 0 0
# 354 SYIC_YEAST.Quant.csv
# 34517 1443 0 0
# 355 SYKC_YEAST.Quant.csv
# 34649 1451 0 0
# 356 SYLC_YEAST.Quant.csv
# 34749 1451 0 0
# 357 SYNC_YEAST.Quant.csv
# 34807 1453 0 0
# 358 SYRC_YEAST.Quant.csv
# 34925 1455 0 0
# 359 SYSC_YEAST.Quant.csv
# 35076 1464 0 0
# 360 SYTC_YEAST.Quant.csv
# 35168 1472 0 0
# 361 SYV_YEAST.Quant.csv
# 35188 1472 0 0
# 362 SYYC_YEAST.Quant.csv
# 35208 1472 0 0
# 363 TAL1_YEAST.Quant.csv
# 35391 1489 0 0
# 364 TBA1_YEAST.Quant.csv
# 35471 1489 0 0
# 365 TBB_YEAST.Quant.csv
# 35491 1489 0 0
# 366 TCTP_YEAST.Quant.csv
# 35571 1489 0 0
# 367 THIL_YEAST.Quant.csv
# 35630 1490 0 0
# 368 THRC_YEAST.Quant.csv
# 35769 1491 0 0
# 369 TIM9_YEAST.Quant.csv
# 35787 1493 0 0
# 370 TKT1_YEAST.Quant.csv
# 36067 1493 0 0
# 371 TMA20_YEAST.Quant.csv
# 36087 1493 0 0
# 372 TPIS_YEAST.Quant.csv
# 36311 1509 0 0
# 373 TPM1_YEAST.Quant.csv
# 36351 1509 0 0
# 374 TPS1_YEAST.Quant.csv
# 36451 1509 0 0
# 375 TRP_YEAST.Quant.csv
# 36667 1513 0 0
# 376 TRX1_YEAST.Quant.csv
# 36766 1514 0 0
# 377 TRX2_YEAST.Quant.csv
# 36823 1517 0 0
# 378 TRXB1_YEAST.Quant.csv
# 36883 1517 0 0
# 379 TSA1_YEAST.Quant.csv
# 37030 1530 0 0
# 380 TSL1_YEAST.Quant.csv
# 37183 1537 0 0
# 381 UBA1_YEAST.Quant.csv
# 37220 1540 0 0
# 382 UCRI_YEAST.Quant.csv
# 37300 1540 0 0
# 383 UGPA1_YEAST.Quant.csv
# 37403 1557 0 0
# 384 VATA_YEAST.Quant.csv
# 37664 1576 0 0
# 385 VATB_YEAST.Quant.csv
# 37997 1583 0 0
# 386 VATE_YEAST.Quant.csv
# 38076 1584 0 0
# 387 VATG_YEAST.Quant.csv
# 38116 1584 0 0
# 388 VATH_YEAST.Quant.csv
# 38136 1584 0 0
# 389 VDAC1_YEAST.Quant.csv
# 38336 1584 0 0
# 390 VPS1_YEAST.Quant.csv
# 38456 1584 0 0
# 391 VPS21_YEAST.Quant.csv
# 38476 1584 0 0
# 392 WTM1_YEAST.Quant.csv
# 38656 1584 0 0
# 393 YCP4_YEAST.Quant.csv
# 38676 1584 0 0
# 394 YGP1_YEAST.Quant.csv
# 38676 1584 0 0
# 395 YHI0_YEAST.Quant.csv
# 38730 1590 0 0
# 396 YL179_YEAST.Quant.csv
# 38750 1590 0 0
# 397 YN034_YEAST.Quant.csv
# 38750 1590 0 0
# 398 YNN4_YEAST.Quant.csv
# 38870 1590 0 0
# 399 YNU8_YEAST.Quant.csv
# 38910 1610 0 0
# 400 YP010_YEAST.Quant.csv
# 38927 1613 0 0
# 401 YP225_YEAST.Quant.csv
# 38983 1617 0 0
# 402 YPT1_YEAST.Quant.csv
# 39000 1620 0 0
# 403 YPT31_YEAST.Quant.csv
# 39020 1620 0 0
# 404 YRB1_YEAST.Quant.csv
# 39040 1620 0 0
# 405 ZEO1_YEAST.Quant.csv
# 39040 1620 0 0
# 406 ZPR1_YEAST.Quant.csv
# 39100 1620 0 0
# 407 ZUO1_YEAST.Quant.csv
# 39180 1620 0 0

# %%
(100*FP/(TN+FP))
# Out:
# 3.9705882352941178
