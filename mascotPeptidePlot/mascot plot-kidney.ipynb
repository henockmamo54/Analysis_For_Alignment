# %%
import numpy as np
import pandas as pd

# %%
data1=[12427,9541,9928,8005,5124,4738,4041,3117,2338,2401,2296,2002]
# data2=[23998,20060,21304,19134,15188,14400,13411,11755,9664,10159,9875,9500]
data2=[23108,19104,20016,17997,14007,12809,11776,9564 ,7601 ,8414 ,8775 ,7375 ]

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(9,6))
bar_width = 0.7
index=np.array([0,1,2,3,6,7,9,13,16,21,24,31])

# '#3CAEA3','#F6D55C','#ED553B','#20639b'

plt.bar(index,data1,bar_width, label= "With out Alignment" ,color='#F6D55C') #ED553B 
plt.bar(index+bar_width+0.1,data1,bar_width, label="With Alignment",color='#20639b')

plt.xticks([0,1,2,3,6,7,9,13,16,21,24,31],[0,1,2,3,6,7,9,13,16,21,24,31])
plt.legend()

# plt.savefig(f"{organ}.jpeg",dpi=900, bbox_inches = "tight")

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(40,15))
plt.rc('font', size=14) 

df=pd.DataFrame()
df["Identity threshold"]=data1
df["Homology threshold"]=data2
df.index=[0,1,2,3,6,7,9,13,16,21,24,31]
df.plot(kind='bar',color={"Identity threshold": "Orange", "Homology threshold": "#20639b"},width=0.75,rot=0,figsize=(9,6))

plt.ylabel("Number of peptides that\n passed the threshold")
plt.xlabel("Labeling duration (Days)")

plt.savefig(f"mascotplot_kidney.jpeg",dpi=900, bbox_inches = "tight")

# %%
df
# Out:
#     Identity threshold  Homology threshold
# 0                12427               23108
# 1                 9541               19104
# 2                 9928               20016
# 3                 8005               17997
# 6                 5124               14007
# 7                 4738               12809
# 9                 4041               11776
# 13                3117                9564
# 16                2338                7601
# 21                2401                8414
# 24                2296                8775
# 31                2002                7375

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(40,15))
plt.rc('font', size=14) 

df=pd.DataFrame()
df["Identity threshold"]=data1
# df["Homology threshold"]=data2
df.index=[0,1,2,3,6,7,9,13,16,21,24,31]
df.plot(kind='bar',color={"Identity threshold": "#ED553B"},width=0.75,rot=0,figsize=(9,6)) #, "Homology threshold": "#20639b"

plt.ylabel("Number of identified peptides ")
plt.xlabel("Labeling duration (Days)")

plt.savefig(f"kidney_Identity.jpeg",dpi=900, bbox_inches = "tight")

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(40,15))
plt.rc('font', size=14) 

df=pd.DataFrame()
# df["Identity threshold"]=data1
df["Homology threshold"]=data2
df.index=[0,1,2,3,6,7,9,13,16,21,24,31]
df.plot(kind='bar',color={"Homology threshold": "#ED553B"},width=0.75,rot=0,figsize=(9,6)) #, "Homology threshold": "#20639b"

plt.ylabel("Number of identified peptides ")
plt.xlabel("Labeling duration (Days)")

plt.savefig(f"kidney_mascotplot_Homology.jpeg",dpi=900, bbox_inches = "tight")

# %%
from matplotlib import pyplot as plt
plt.figure(figsize=(40,15))
plt.rc('font', size=14) 

df=pd.DataFrame() 
df["Homology threshold"]=data2
df.index=[0,1,2,3,6,7,9,13,16,21,24,31]
df.plot(kind='bar',color="#20639b",width=0.55,rot=0,figsize=(9,6),legend=False) #, "Homology threshold": "#20639b"
plt.legend()

plt.ylabel("Number of PSMs ")
plt.xlabel("Labeling duration (Days)")
plt.gca().get_legend().remove()
plt.savefig(f"mascotplot_Homology_kidney.jpeg",dpi=900, bbox_inches = "tight")
